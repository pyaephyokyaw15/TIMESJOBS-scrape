# %% [markdown]
# # [TIMESJOBS](https://www.timesjobs.com)

# %% [markdown]
# * This notebook scrape data on all pages on TIMESJOBS website based on user input.
#
# * This notebook goes step by step.
#
# * If you want to fecth data on all pages instantly, check [here.](https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=&cboWorkExp1=20)

# %%
# !pip install beautifulsoup4

# %%
# !pip install lxml

# %%
# import modules
from bs4 import BeautifulSoup
import requests

# %%
base_url = 'https://www.timesjobs.com/'
job = input('Job: ')
experience = input("Enter only number.\nFor all experience, only press 'enter'.\nExperience: ")
# Out:
# Job: python
# Enter only number.
# For all experience, only press 'enter'.
# Experience: 15

# %%
'''
Sample URL

https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch
&from=submit&txtKeywords=python&txtLocation=&cboWorkExp1=20

'''

# generate url based on user input
url = base_url + '/candidate/job-search.html?from=submit&txtKeywords=' + job+'&cboWorkExp1='+experience

# %%
#  fetch HTML text
html_text = requests.get(url).text
print(html_text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <head>
#
#
#
# <script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"2a67c1bd6d",applicationID:"96890711"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n){return function(){return o(t,[u.now()].concat(f(arguments)),e?null:this,n),e?void 0:this}}var o=t("handle"),a=t(8),f=t(9),c=t("ee").get("tracer"),u=t("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var d=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],p="api-",l=p+"ixn-";a(d,function(t,e){s[e]=i(p+e,!0,"api")}),s.addPageAction=i(p+"addPageAction",!0),s.setCurrentRouteName=i(p+"routeName",!0),e.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(t,e){var n={},r=this,i="function"==typeof e;return o(l+"tracer",[u.now(),t,n],r),function(){if(c.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return e.apply(this,arguments)}catch(t){throw c.emit("fn-err",[arguments,this,t],n),t}finally{c.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(t,e){m[e]=i(l+e)}),newrelic.noticeError=function(t,e){"string"==typeof t&&(t=new Error(t)),o("err",[t,u.now(),!1,e])}},{}],2:[function(t,e,n){function r(t){if(NREUM.init){for(var e=NREUM.init,n=t.split("."),r=0;r<n.length-1;r++)if(e=e[n[r]],"object"!=typeof e)return;return e=e[n[n.length-1]]}}e.exports={getConfiguration:r}},{}],3:[function(t,e,n){function r(){return f.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,f=t(10);e.exports=r,e.exports.offset=a,e.exports.getLastTimestamp=i},{}],4:[function(t,e,n){function r(t){return!(!t||!t.protocol||"file:"===t.protocol)}e.exports=r},{}],5:[function(t,e,n){function r(t,e){var n=t.getEntries();n.forEach(function(t){"first-paint"===t.name?d("timing",["fp",Math.floor(t.startTime)]):"first-contentful-paint"===t.name&&d("timing",["fcp",Math.floor(t.startTime)])})}function i(t,e){var n=t.getEntries();n.length>0&&d("lcp",[n[n.length-1]])}function o(t){t.getEntries().forEach(function(t){t.hadRecentInput||d("cls",[t])})}function a(t){if(t instanceof m&&!g){var e=Math.round(t.timeStamp),n={type:t.type};e<=p.now()?n.fid=p.now()-e:e>p.offset&&e<=Date.now()?(e-=p.offset,n.fid=p.now()-e):e=p.now(),g=!0,d("timing",["fi",e,n])}}function f(t){"hidden"===t&&d("pageHide",[p.now()])}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var c,u,s,d=t("handle"),p=t("loader"),l=t(7),m=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){c=new PerformanceObserver(r);try{c.observe({entryTypes:["paint"]})}catch(v){}u=new PerformanceObserver(i);try{u.observe({entryTypes:["largest-contentful-paint"]})}catch(v){}s=new PerformanceObserver(o);try{s.observe({type:"layout-shift",buffered:!0})}catch(v){}}if("addEventListener"in document){var g=!1,h=["click","keydown","mousedown","pointerdown","touchstart"];h.forEach(function(t){document.addEventListener(t,a,!1)})}l(f)}},{}],6:[function(t,e,n){function r(t,e){if(!i)return!1;if(t!==i)return!1;if(!e)return!0;if(!o)return!1;for(var n=o.split("."),r=e.split("."),a=0;a<r.length;a++)if(r[a]!==n[a])return!1;return!0}var i=null,o=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var f=navigator.userAgent,c=f.match(a);c&&f.indexOf("Chrome")===-1&&f.indexOf("Chromium")===-1&&(i="Safari",o=c[1])}e.exports={agent:i,version:o,match:r}},{}],7:[function(t,e,n){function r(t){function e(){t(a&&document[a]?document[a]:document[i]?"hidden":"visible")}"addEventL ...
# 		<link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">
# 		<link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.7" rel="stylesheet" type="text/css" media="all"/>
# 		<link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.7" rel="stylesheet" type="text/css" media="all"/>
#        <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.7" rel="stylesheet" type="text/css" media="all"/>
#       	<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js"></script>
# 		<!-- <script type="text/javascript" src="https://code.angularjs.org/1.7.0/angular.min.js"></script> -->
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/angular1.7.0.min.js"></script>
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/materialize.min.js"></script>
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/groupJs/dwrGroup.js?v=7.1.7"></script>
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/mustache.js"></script>
#
#
#         <link rel="canonical" href="https://www.timesjobs.com/candidate/job-search.html"/>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 						<link rel="next" href="https://www.timesjobs.com/candidate/job-search.html?from=submit&txtKeywords=python&cboWorkExp1=15/&sequence=2&startPage=1"/>
#
#
#
#
#
#
#
#
#
# 				<title>python Jobs with 15 years experience - TimesJobs</title>
#
#
#
#
# 			<meta name="description" content="Jobs in python with 15 years experience. Search and apply jobs online at Timesjobs.com"/>
#
#
# 		<!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-59SJDG4');</script>
# <!-- End Google Tag Manager -->
# <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#         <script>
#           //google.charts.load('current', {'packages':['bar']});
#           google.charts.load('current', {packages: ['corechart', 'bar']});
#         </script>
#
# </head>
#   	<body>
#   		<div id="site">
#
#
# 				<!-- Header Starts -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# 	<iframe src="https://www.googletagmanager.com/ns.html?id=GTM-59SJDG4"
# 		height="0" width="0" style="display:none;visibility:hidden"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <!--[if IE]>
# <script src="scripts/html5shiv.js"></script>
# <![endif]-->
#
# <script type="text/javascript" src='https://static.timesjobs.com/newtj_js/scripts/ajax-upload.js' ></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		<div id="fb_connect_suggest" style="display: none;" class="msg notify">
# 		Dear Jobseeker, Find millions of jobs on single click.
# 		<span id="fb_auto_connect"><a href="javascript:fconnect_auto();"><img src='https://static.timesjobs.com/images_cand/tj_images/personlisation/top-facebook-notify.png' alt='fconnect'></a></span>
# 		<span class="big-cls cls-icn" title="Click to Hide" onclick="javascript:ack_fbconnect_cancel();"><i class="material-icons">close</i></span>
# 		<span id="fb_connect_status"></span>
# 		</div>
# 		<div id="fb_connect_success" style="display: none;" class="msg success">
# 			Congratulations! You have been logged in via Facebook
# 		</div>
#
#
#
#
# <header class="main-header">
# <div class="top-header">
# 	<div class="ubility-wrap clearfix">
# <ul class="top-link">
#     <li><a href="https://www.timesjobs.com" class="link-active">TimesJobs</a></li>
#     <li><a href="http://jobbuzz.timesjobs.com" target="_blank">JobBuzz</a></li>
#     <!--<li><a href="http://stepahead.timesjobs.com" target="_blank">Career Services</a></li>
#      <li><a href="http://www.techgig.com" target="_blank">TechGig</a></li> -->
#     <li><a href="https://ae.timesjobs.com" target="_blank">Gulf Jobs</a></li>
#     <li><a href="http://content.timesjobs.com/recruitex?fromsite=tjcand" target="_blank">Career Insight</a></li>
#   </ul>
#
# <ul class="top-contact">
# 	 <li><i class="material-icons">call</i>0120 6358222</li>
#     <li>
#
#        	   <span id="chat-widget" class="live-chat">Live Chat (10am to 6pm IST)</span>
#
#     </li>
# 	</ul>
# 	</div>
# 	</div>
# 	<div class="ubility-wrap logo-section clearfix">
#
#
#
#
#
#
# 		<a itemprop="url" title="TIMESJOBS" href="https://www.timesjobs.com" class="top-tj-logo">
# 			<img src="https://static.timesjobs.com/images_cand/tj_images/personlisation/tj-logo-new.png" alt="TimesJobs" width="140" height="23" title="TimesJobs" itemprop="logo">
# 		</a>
#
#
#
#
#
#
#
#
#
#
#
#
# <div id="career-affection" class="career-affection top-notifi notify-msg covid-home-page" style="display:none">
# 		<div class="career-affection-inner wrap career-effect" id="career-affection-inner ">
# 			Is your career affected by Covid-19?
# 			<a href="javascript:void(0);" onclick="profilePreview.covidAffectedProfile('Y','TJWEB');" class="yes-button">Yes</a> <a
# 				href="javascript:void(0);" onclick="profilePreview.covidAffectedProfile('N','TJWEB');" class="no-button">No</a>
# 		</div>
# 	</div>
#
#
#
#
#
#
#
#
#
#
# 			<script type="text/javascript">
# 				jQuery(document).ready(function() {
# 					jQuery("#career-affection").show();
# 					jQuery("#career-affection-rhs").show();
# 				})
# 			</script>
#
#
#
#
#
#
#
# 	  <ul class="main-tj-nav clearfix">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# var notification_timeout = 10000;
# var notification_cache = true;
# if (!window.console) console = {log: function() {}};
#
# if(typeof String.prototype.trim !== 'function') {
#   String.prototype.trim = function() {
#     return this.replace(/^\s+|\s+$/g, '');
#   }
# }
#
#
# /* This function is used to set cookies */
# function setCookie(name,value,expires,path,domain,secure) {
#   document.cookie = name + "=" + escape (value) +
#     ((expires) ? "; expires=" + expires.toGMTString() : "") +
#     ((path) ? "; path=" + path : "") +
#     ((domain) ? "; domain=" + domain : "") + ((secure) ? "; secure" : "");
# }
#
# /* This function is used to get cookies */
# function getCookie(name) {
# 	var prefix = name + "=" ;
# 	var start = document.cookie.indexOf(prefix);
#
# 	if (start==-1) {
# 		return null;
# 	}
#
# 	var end = document.cookie.indexOf(";", start+prefix.length);
# 	if (end==-1) {
# 		end=document.cookie.length;
# 	}
#
# 	var value=document.cookie.substring(start+prefix.length, end) ;
# 	return unescape(value);
# }
#
#
# function deleteCookie(name,path,domain) {
#   if (getCookie(name)) {
#     document.cookie = name + "=" +
#       ((path) ? "; path=" + path : "") +
#       ((domain) ? "; domain=" + domain : "") +
#       "; expires=Thu, 01-Jan-70 00:00:01 GMT";
#   }
# }
#
# var authenticated = 'false';
#
# jQuery(document).ready(function(){
# var alreadyCalled = false;
#
# //alert("logged-in:"+authenticated);
# //alert("comparison to true, for"+authenticated +", "+ ('true' == authenticated));
#
# if('true' == authenticated){
# 	//jQuery(".viewnoteTab").mouseout(function(){
# //	  jQuery(".showdiv").hide();
# //	});
# //	jQuery(".viewnoteTab").mouseenter(function(){
# //	  jQuery(".showdiv").show();
# //	});
# 	//alert("logged in ");
# }else{
# 	//alert("not logged in ");
# 	jQuery(".notif-cls").on("click",function(){
# 		//alert('hi');
# 	  jQuery("#inline_login").hide();
# 	  //jQuery(".notification .nav-drop").hide();
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# 	updateNonLoggedInUsersTime();
# }
# function updateNonLoggedInUsersTime(){
# 	//alert("non_loggedin_time:"+getCookie('non_loggedin_time'));
# 	var setCookieForTime = getCookie('non_loggedin_time');
# 	if(null!=setCookieForTime){
# 		//alert("cookie found to be set to : "+setCookieForTime+" where time since is:"+timeSince(setCookieForTime));
# 		jQuery("#non_loggedin_time").html(timeSince(setCookieForTime));
# 	}else{
# 		var currentTime = new Date().getTime();
# 		setCookie('non_loggedin_time',currentTime);
# 	}
# }
#
# jQuery(".viewnote").on("click",function(){
# 	var loggedInClicked = getCookie('loggedin_click');
# 	if(null!=loggedInClicked){
# 		jQuery("#notification_count").css("background-color","#075DC1");
# 	}else{
# 		if('true' == authenticated){
# 			setCookie('loggedin_click',1);
# 			//alert("setting loggedInClicked");
# 		}
# 	}
# });
#
# });
#
# </script>
# <!--- view notification section begin --->
#  <li class="notification viewnote">
# 	<a class='dropdown-button' href='#' data-activates='notifyDropdown'>
# 		<i class="material-icons left">notifications_none</i>
# 		<span id="notification_count" class="notif-count-new">1</span>&nbsp;
# 	</a>
# 	<div class="nav-drop viewnoteTab dropdown-content" id='notifyDropdown'>
# 	<div class="showdiv">
# 		<div id="non_loggedin" class="notif-not-logedin" style="display:none;">
# 			<div class="notif-welcm-msg clearfix">To see all recommended jobs, profile views, recruiter's contacted information, updates and more...</div>
# 	 			<div class='notif-act clearfix'>
#
#
#
# 						<button type='button' class='waves-effect waves-light btn red-bdr-btn' onclick="javascript:openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');">Login</button>
#
#
# 				<strong class='or'>or</strong>
# 				<a href="/candidate/register.html" class='waves-effect waves-light btn red-bdr-btn' >Register</a>
# 	    	</div>
# 	   	</div>
#
#
#
# 		<!-- INLINE LOGIN PAGE -->
#
# 		<div id="inline_login" class="notif-login-frm" style="display:none;">
#         <span class="notif-cls" title="Click to Hide"></span>
#
#
#
# 			  <strong>Login to View Notifications!</strong>
#
#
# 		<form action="/candidate/times_login?BeforeLoginUrl=notification&tab=1" method="post" name="loginFormNotification">
#
#
#
#
# 				    <input name="j_username" id="txtUseNameNotification" type="text" onblur="javascript:settextNotification('txtUseNameNotification');" onClick="filltxtNotification(txtUseNameNotification)" value="Enter Email id / Login id" class="txt2 defaultValue inpt-typ" size="42" />
#
#
# 		    <input name="j_password" type="password" value="" class="password_input_notification" size="42"  style="display:none" />
#             <input type="text" value="Enter Password" class="clearNotification" size="42" />
#             <div class="frgt-pass"><a href="javascript:forgotPasswordNotification();" class="fp">Forgot Password?</a></div>
#
# 	      <input class="" type="submit" onClick="javascript:return validateLoginFormNotification();" value="Login" />
#
#           <div class="error-msg dflt-msg" id="loginErrNotification" style="display:none;">
#            	      <!--<img class="errTip" title="Error" alt="Error" src="https://static.timesjobs.com/images_cand/tj_images/home/errTipL.gif">-->
#                   <!--<a class="errCls" href="#"><img border="0" title="Close" alt="Close" src="/images_cand/tj_images/home/logginErrClse.gif"></a>-->
#        	      Login-ID/Password cannot be left blank. Enter the full email ID (like: ram@gmail.com), if you are using registered email-id for login.
# 	      </div>
#
#   	    <input type="hidden" name="notlogin" value="mytj">
# 		  <input type="hidden" name="_acegi_security_remember_me" value="yes">
# 	    </form>
# 	    </div>
#
# 		<!-- INLINE LOGIN PAGE -->
#                        <div id="base" style="display: none;" class="notif-main">
# 						   <ul>
# 	                       	   <li id="heading" class="heading clearfix">
# 	                       	   	<a id="heading-link" href="#"><span>Job Alerts(10)</span></a>
# 	                       	   </li>
# 		                       		<li id="base-li" style="display: none;"><a id="base-li-anchor" href="#">5 Matching Jobs <span id="base-li-time">3 hrs ago</span></a>
# 		                       		</li>
# 		                       		<span id="base-li-data" style="display: none;"  class="base_li"></span>
# 		                       </ul>
#                        </div>
#                        </div>
#           </div>
# 	  	  </li>
#
#                     <!--- view notification section ends here --->
#
#
# 	<script type="text/javascript">
#
# function forgotPasswordNotification(){
# 		GB_showCenter('Forgot Password','/candidate/ForgetPassword.html',180,420);
# 	}
# var race = 0;
# function showNotificationLoginThickBox(){
#
# race = 1;
#
# 			//jQuery("#inline_login").addClass('notifyshow');
# 			//jQuery('.viewnoteTab').addClass('notifyshow');
# 			//jQuery('.showdiv').addClass('notifyshow');
# 			//jQuery(".notif-not-logedin").hide();
# 			//jQuery(".notification .nav-drop").css('display','block');
# 			//jQuery(".notification").addClass("notifi");
# 			jQuery('.clearNotification').css({color:"#b3b3b3"});
# 					jQuery('.clearNotification').focus(function(){
# 						//alert('check');
# 						jQuery(this).hide();
# 						jQuery(' .password_input_notification').show();
# 						jQuery('.password_input_notification').focus();
# 					});
# 					jQuery('.password_input_notification').blur(function(){
# 						if(this.value==''){
# 						jQuery(this).hide();
# 							jQuery('.clearNotification').show();
# 						}
# 					});
#
#
#
# }
# jQuery(".notif-cls").on("click",function(){
# 	  //jQuery("#inline_login").removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.viewnoteTab').removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.showdiv').removeClass('notifyshow');
#
# 	 // jQuery(".notif-not-logedin").show();
# 	 jQuery(".notif-not-logedin").css('display','');
# 	  //jQuery(".notification .nav-drop").css('display','none');
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# jQuery(".viewnote").mouseenter(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").show();
#   //jQuery(".notification .nav-drop").show();
#
#   if('false' == authenticated){
#     var hideCountCookie = getCookie('hide_nologgedin_count');
#     if(null == hideCountCookie){
#   		setCookie('hide_nologgedin_count',1);
#   		//alert("setting hide_nologgedin_count");
#   	}else{
#   		jQuery("#notification_count").hide();
#   	}
#   }else{
#    jQuery("#inline_login").hide();
#    jQuery("#non_loggedin").hide();
#
#    	updateNotificationComponentWithIECheck();
#   }
#
# });
# jQuery(".viewnote").mouseleave(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").hide();
#   //jQuery(".notification .nav-drop").hide();
# });
# jQuery(".notif-login-frm").mouseleave(function(){
# //alert("mouseenter called..");
#   event.stopPropagation()
# });
# function settextNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value !=''){
# 			document.getElementById(id).checked=true;
# 		}else{
# 			document.getElementById(id).checked=false;
# 			document.getElementById('txtUseNameNotification').value='Enter Email id / Login id';
# 			document.getElementById('txtUseNameNotification').style.color='#999'
# 		}
# 	}
# function filltxtNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id')
# 			document.getElementById('txtUseNameNotification').value=''
# 		document.getElementById('txtUseNameNotification').style.color='#333'
# 	}
# function validateLoginFormNotification(){
# var status = true;
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id'){
# 			document.getElementById('txtUseNameNotification').value='';
# 			status =  false;
# 		}
#
# 		if(checkBlankNotification(document.loginFormNotification.j_username,"Login ID")){
# 			status =  false;
# 		}
# 		if(checkBlankNotification(document.loginFormNotification.j_password,"Password")){
# 			status =  false;
# 		}
# 		//update_notification_cookie
# 		if(status){
# 			deleteCookie('update_notification_cookie');
# 		}
# 		return status;
# 	}
# function checkBlankNotification(field,name){
# 		if(field.value.trim() == ""){
# 			field.value = "";
# 			field.focus();
# 			document.getElementById("loginErrNotification").style.display="";
# 			return true;
# 		}
# 		return false;
# 	}
#
# var diff = 1627013549-((new Date().getTime())/1000);
#
#
# function ellipsize(str, len) {
# 	if(str.length > len) {
#  		return str.substr(0,len) + "...";
# 	} else {
# 		return str;
# 	}
# }
#
# function timeSince(previous){
#
# 	current =  new Date().getTime()+diff;
# 	var milleSecondsPerMinute = 60 * 1000;
#     var milleSecondsPerHour = milleSecondsPerMinute * 60;
#     var milleSecondsPerDay = milleSecondsPerHour * 24;
#     var milleSecondsPerMonth = milleSecondsPerDay * 30;
#     var milleSecondsPerYear = milleSecondsPerDay * 365;
#
#     var elapsed = current - previous;
#
#     if (elapsed < milleSecondsPerMinute) {
#          value = Math.round(elapsed/1000) + ' seconds ago';
#     }
#
#     else if (elapsed < milleSecondsPerHour) {
#     	value = Math.round(elapsed/milleSecondsPerMinute) + ' minutes ago';
#     }
#
#     else if (elapsed < milleSecondsPerDay ) {
#     	value = Math.round(elapsed/milleSecondsPerHour ) + ' hours ago';
#     }
#
#     else if (elapsed < milleSecondsPerMonth) {
#     	value =  Math.round(elapsed/milleSecondsPerDay) + ' days ago';
#     }
#
#     else if (elapsed < milleSecondsPerYear) {
#     	value = Math.round(elapsed/milleSecondsPerMonth) + ' months ago';
#     }
#
#     else {
#     	value = Math.round(elapsed/milleSecondsPerYear ) + ' years ago';
#     }
#     //return (value);
#     return (value);
# }
#
#
# function updateNotificationComponent(){
#  alreadyCalled  =true;
# 	var context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  context="/candidate/";
# 		  //alert("bingo");
# 	}
#
#
# 	ajaxController.getLoginId(function(response){
# 	//alert("updateNotificationComponent,response:"+response)
# 		if (response != null && response.trim().length > 0) {
# 			jQuery.ajax({
# 							cache:notification_cache,
# 							timeout:notification_timeout,
# 							url:context+"inbox-notifications.html?from=submit",
# 							success:function(data){
# 							var trimLength = 30;
# 									jQuery("#base_ja").remove();
# 									jQuery("#base_j").remove();
# 									jQuery("#base_rv").remove();
# 									//alert(data);
# 									var parsedData = JSON.parse(data);
# 									var theCount = parsedData["count"];
#
# 									var jaCount = parsedData["jaCount"];
# 									var jCount = parsedData["jCount"];
# 									var rvCount = parsedData["rvCount"];
#
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
# 									//theCount = theCount - jCount;
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
#
# 									if(theCount >= 0){
# 										if(theCount >= 0){
# 											if(theCount <99){
# 												jQuery("#notification_count").html(theCount);
# 												setCookie('notification_cookie_count',theCount);
# 											}else{
# 												jQuery("#notification_count").html("99+");
# 												setCookie('notification_cookie_count',"99+");
# 											}
# 										}
#
# 										var isNew = parsedData["new"];
# 										//alert("new:"+(isNew == true));
# 										if(isNew == true){
# 											jQuery("#notification_count").css("background-color","red");
# 											setCookie('notification_cookie_color','red');
# 											deleteCookie('loggedin_click');
# 										}else{
# 											var loggedInClicked = getCookie('loggedin_click');
# 											//alert("loggedInClicked:"+loggedInClicked);
# 											if(null!=loggedInClicked){
# 												jQuery("#notification_count").css("background-color","#075DC1");
# 												setCookie('notification_cookie_color','#075DC1');
# 											}else{
# 												jQuery("#notification_count").css("background-color","red");
# 												setCookie('notification_cookie_color','red');
# 											}
#
# 										}
# 									}
# 									jQuery("#notification_count").show();
#
# 									/* alert("count:"+parsedData["count"]);
# 									alert("jaCount:"+parsedData["jaCount"]);
# 									alert("jCount:"+parsedData["jCount"]);
# 									alert("rvCount:"+parsedData["rvCount"]); */
#
# 									/**
# 									start-JA
# 									*/
# 									if(jaCount){
# 										if(jaCount <25){
# 											jQuery("#base .heading span").html("Job alerts ("+jaCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Job alerts (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Job alerts");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jaData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jaData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jaData"])[i].subject;
# 										var since = timeSince(JSON.parse(parsedData["jaData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=1&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_ja_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_ja");
# 									//alert("jaData[0]:"+ (JSON.parse(parsedData["jaData"]).length));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-JA
# 									*/
#
# 									/**
# 									start-J
# 									*/
# 								   if(jCount){
# 									 	if(jCount <25){
# 											jQuery("#base .heading span").html("Mails from recruiters ("+jCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Mails from recruiters (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Mails from recruiters");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jData"])[i].EmployerName + " contacted you.";
# 										var since = timeSince(JSON.parse(parsedData["jData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=2&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_j_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_j");
# 									//alert("jData[0]:"+timeSince(JSON.parse(parsedData["jData"])[0].creationTime));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-J
# 									*/
#
# 									/**
# 									start-RV
# 									*/
# 									if(rvCount > 0){
# 										if(rvCount <25){
# 											jQuery("#base .heading span").html("Who's viewed your profile ("+rvCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Who's viewed your profile (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Who's viewed your profile");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["rvData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["rvData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["rvData"])[i].subject;
# 										var employerName = JSON.parse(parsedData["rvData"])[i].EmployerName + " viewed your resume.";
# 										var since = timeSince(JSON.parse(parsedData["rvData"])[i].creationTime);
# 										if(null!=employerName && employerName.length > 0){
# 											jQuery("#base-li-anchor").html(ellipsize(employerName,trimLength));
# 											jQuery("#base-li-anchor").attr("title",employerName);
# 										}else{
# 											jQuery("#base-li-anchor").html("Resume Viewed");
# 										}
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=5&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_rv_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_rv");
# 									//alert("rvData[0]:"+timeSince(JSON.parse(parsedData["rvData"])[0].employerName));
# 									jQuery("#base > ul span.base_li").html("");
# 									/**
# 									end-RV
# 									*/
#
# 									jQuery("#base").hide();
# 									jQuery("li#base-li").hide();
# 								},
# 							complete:function(){
# 								console.log("complete... inbox-notifications");
# 								jQuery("#inline_login").hide();
#    								jQuery("#non_loggedin").hide();
#    								alreadyCalled  = false;
# 							},
# 							error: function(x, t, m) {
# 								console.log("Error message"+m);
# 								 var randomnumber=Math.floor(Math.random()*100000001);
# 								 var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+context+"inbox-notifications.html?from=submit"+'&op=respTracking#'+randomnumber;
# 								 ping(nlpurl);
# 						        jQuery("#error").show();
# 							}
# 						});
#
# 		}else{
# 					jQuery("#base_ja").remove();
# 					jQuery("#base_j").remove();
# 					jQuery("#base_rv").remove();
# 					if(0 == race){
# 						jQuery("#non_loggedin").show();
# 					}
#
#
# 					var hideCountCookie = getCookie('hide_nologgedin_count');
# 					if(null != hideCountCookie){
# 						/*This is commented because for non logged in user default count 1 is being hidden.*/
# 						//jQuery("#notification_count").hide();
# 					}else{
# 						jQuery("#notification_count").css("background-color","red");
# 						jQuery("#notification_count").show();
# 					}
# 					alreadyCalled  = false;
# 		}
# 	});
# }
#
# var updateNotificationCookie = getCookie('update_notification_cookie');
# //alert("updateNotificationCookie: "+updateNotificationCookie);
# if(null == updateNotificationCookie || updateNotificationCookie==''){
# 	updateNotificationComponentWithIECheck();
# 	setCookie('update_notification_cookie',1);
# 	//alert("cookie set");
# 	scheduleNotificationCookieToDie();
# }else{
# 	if('true' == authenticated){
# 		//alert("updating from cookie!!!");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		if(null==notificationCookieCount){
# 			updateNotificationComponent();
# 		}
# 		updateNotificationFromCookie();
# 	}else{
# 		//alert("not updating from cookie!!!");
# 		updateNotificationComponentWithIECheck();
# 	}
# }
#
# function scheduleNotificationCookieToDie(){
# 	setTimeout(function() {
# 	      deleteCookie('update_notification_cookie');
# 	      deleteCookie('notification_cookie_count');
# 	      deleteCookie('notification_cookie_color');
# 	},5*60*1000);
# }
#
# function updateNotificationFromCookie(){
# console.log("cookie set for updateNotificationCookie, not making server call.");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		//alert("not setting cookie"+updateNotificationCookie);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").html(""+notificationCookieCount);
# 		}else{
# 			jQuery("#notification_count").html("1");
# 		}
# 		var notificationCookieColor = getCookie('notification_cookie_color');
# 		//alert("cookie color"+notificationCookieColor);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").css("background-color",notificationCookieColor);
# 		}else{
# 			jQuery("#notification_count").css("background-color","red");
# 		}
# 		jQuery("#notification_count").show();
# }
#
# function updateNotificationComponentWithIECheck(){
# <!--[if gte IE 9]>
# 		updateNotificationComponent();
# 	<!--<![endif]-->
# 	<!--[if lt IE 9]>
#    		jQuery(document).ready(function() {
# 			updateNotificationComponent();
# 		});
# 	<!--<![endif]-->
# }
#
# </script>
#
#
#
#
#
#
#
#
#
# 				<li class="login-reg">
# 					<a href="javascript:void(0);" onclick="openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');">Login</a>
# 				</li>
#
#
# 		<li class="login-reg">
#
# 				<a href="/candidate/register.html?pageFlow=TJ_SEARCH">Register</a>
#
#
# 		</li>
#
# 	</ul>
#
#
# 	</div>
# </header>
# 	<!--bottom banner starts-->
#
#           <!--bottom banner ends-->
#
#
#
#
#
# 			<div class="open-search ">
#
#
#
#
#
#
# <div class="usability-srch clearfix">
#   <div class="main-srch-form clearfix">
# 	  <div id="errorMsgDiv" class="msg error" style="display:none">Please provide inputs for at least one field</div>
#        <form id="quickSearchBean" name="quickSearchBean" action="https://www.timesjobs.com/candidate/job-search.html" method="get"  onSubmit="return searchEngine.validateSearchForm(this);" >
#
#           	<input name="searchType" value="personalizedSearch" type="hidden">
#           	<input name="from" value="submit" type="hidden">
#           	<div class="auto-suggest-blk">
#
#
#
#
#             <input id="txtKeywords" name="txtKeywords" type="text"  value="python" class="browser-default"/>
#             <div id="autoSuggestList" style="display:none;"><ul></ul></div><iframe id="FrameautoSuggestList" frameborder="0" style="display:none;"></iframe>
#             <div id="autoSuggestList2ndKeywordsListSFB" class="suggestionList srch-suggest" style="display:none;">
#               <h5>Suggested Keywords</h5>
#           <ul></ul></div>
#           </div>
#         <div class="auto-suggest-blk location-srch">
#
#
#   <input id="txtLocation" name="txtLocation" type="text" class="location-srch browser-default" value="Enter Location"/><div id="autoSuggestLocation" style="display:none;"><ul></ul></div><iframe id="FrameautoSuggestLocation" style="display:none" frameborder="0"></iframe></div>
#       <div class="srch-select">
#           <select id = "cboWorkExp1" name="cboWorkExp1" class="browser-default">
#
#
#
#                       <option value="-1" >Experience</option>
#
#
#
#                       <option value="0" >Entry Level</option>
#
#
#
#                       <option value="1" >1 year</option>
#
#
#
#                       <option value="2" >2 years</option>
#
#
#
#                       <option value="3" >3 years</option>
#
#
#
#                       <option value="4" >4 years</option>
#
#
#
#                       <option value="5" >5 years</option>
#
#
#
#                       <option value="6" >6 years</option>
#
#
#
#                       <option value="7" >7 years</option>
#
#
#
#                       <option value="8" >8 years</option>
#
#
#
#                       <option value="9" >9 years</option>
#
#
#
#                       <option value="10" >10 years</option>
#
#
#
#                       <option value="11" >11 years</option>
#
#
#
#                       <option value="12" >12 years</option>
#
#
#
#                       <option value="13" >13 years</option>
#
#
#
#                       <option value="14" >14 years</option>
#
#
#
#
#
#                       <option value="15" selected='selected'>15 years</option>
#
#
#
#                       <option value="16" >16 years</option>
#
#
#
#                       <option value="17" >17 years</option>
#
#
#
#                       <option value="18" >18 years</option>
#
#
#
#                       <option value="19" >19 years</option>
#
#
#
#                       <option value="20" >20 years</option>
#
#
#
#                       <option value="21" >20+ years</option>
#
#           </select>
#       </div>
#           <button class="waves-effect waves-light btn" value="Search" onclick="javascript:setAClickOnSearch();">Find Jobs</button>
#
#       </form>
#   </div>
# <div id="recentSearchId" class="recent-srchs home-srchptext srch-top-right" style="display: none;"></div>
#
#   <div class="upload-res-uni srch-top-right clearfix" id="resNewUpload" style="display:none;">
#     <div class="upload-res-txt clearfix">
#       <span class="upload-icon"></span>
#       <div class="upload-res-input">
#         <h5>New to Timesjobs?</h5>
#         <label class="upload-res-btn" id="uploadResume_basic">
#           upload your resume
#           <input name="resumeFile_basic" id="resumeFile_basic" size="25" type="file" />
#           </label>
#         <span id="uploadingResume_basic" style="display:none"><img src="https://static.timesjobs.com/images_cand/tj_images/personlisation/loader.gif" alt="Uploading Resume"></span>
#         </div>
#       </div>
#   </div>
#
#    </div>
# <script type="text/javascript">
#   var ssCounterSFB=0;
# 	function openSecondSuggestionSFB(theSelectedSuggestionText){
# 		if(ssCounterSFB < 5){
# 			ajaxController.getSuggestedSkillList(theSelectedSuggestionText,"","SKILL",8,true,cb_openSecondSuggestionSFB);
# 		}else{
# 			console.log("CAND-131 Not showing 2nd suggestion.");
# 		}
# 	}
#
# 	function cb_openSecondSuggestionSFB(result){
# 		//alert("cb_openSecondSuggestion:"+result);
# 		var splitData = (""+result).split(",");
# 		var li_data = "";
# 		var dataLength = splitData.length;
# 	    var text = jQuery("#txtKeywords").val();
# 	    text =text.toLowerCase();
# 	    if(dataLength >1){
# 			for(i=0;i<dataLength;i++){
# 	            if(text.indexOf(splitData[i].toLowerCase()) < 0){
# 	                var hyperlink =  "javascript:secondSelectionClickedSFB('"+encodeURI(splitData[i])+"');";
# 					li_data+="<li><a href="+hyperlink+">"+splitData[i]+"</a></li>";
# 				}
# 			}
# 			jQuery("#autoSuggestList2ndKeywordsListSFB ul").html(li_data);
# 			jQuery("#autoSuggestList2ndKeywordsListSFB").slideDown(300);
# 			//ssCounterSFB = ssCounterSFB  + 1;
# 		}
# 	}
#
# 	function secondSelectionClickedSFB(that){
# 		//alert("that:"+that);
# 		_gaq.push(['_trackEvent','Click2Ad','tj_skillsuggestion']);
# 		jQuery("#autoSuggestList2ndKeywordsListSFB").hide();
# 		var text = jQuery("#txtKeywords").val();
# 		var text2 = text.toLowerCase() + ",";
# 		var that2 = that.toLowerCase();
# 		var res = text2.split(",");
# 		var exists = false;
# 		for(i in res){
# 			if(null!=res[i] && res[i].length > 0 && res[i]+"".trim() === that2){
# 				exists = true;
# 				break;
# 			}
# 		}
# 		//var index = text2.search(new RegExp(that2, "i"));
# 		//console.log("exists:"+exists);
# 		if(!exists){
# 			jQuery("#txtKeywords").val(text +","+ that);
# 			jQuery("#txtKeywords").focus();
# 		}
# 		openSecondSuggestionSFB(that);
# 	}
# jQuery(document).ready(function(){
# 	jQuery('#quickSearchBean input[type="text"]').DefaultInputValue();
# })
#
# function BasicResFileUpload(){
# 		//alert('uploaded re loaded');
# 		new AjaxUpload('resumeFile_basic', {
# 			action:'/candidate/servlet/FileUploadServlet',
# 			//responseType: 'json',
# 			responseType: 'true',
# 			name: 'resumeFile_basic',
# 			onSubmit : function() {
# 				//alert('11');
# 				document.getElementById("uploadResume_basic").style.display="none";
# 				document.getElementById("uploadingResume_basic").style.display="block";
# 			},
# 			onComplete : function(file,response){
# 				var displayFilename=file;
# 				if(file.length >18){
# 					displayFilename=file.substring(0,18)+"..";
# 				}
# 				response = response.replace(/'/g , '"');
# 				var jsonObj = jQuery.parseJSON(response);
# 				jsonObj["filename"] = displayFilename;
# 				ajaxController.setSessionAttribute('tjindexResumeUploadMsg', jsonObj["MESSAGE"]);
# 				response = JSON.stringify(jsonObj);
# 				ajaxController.setSessionAttribute('tjindexResumeUpload', response);
# 				//window.open('/candidate/register.html', '_blank');
# 				window.location ='/candidate/register.html';
# 			}
# 		});
# 	}
# 	BasicResFileUpload();
#   </script>
# 			</div>
#
#
#
#
#
# <script>
# var name='null';
# var phone='null';
# var email='null';
# //alert("name"+name);
# //alert("phone Num"+phone);
# if((phone!=null && $.trim(phone).length>0)&& phone.indexOf("+91-")!=-1){
#    phone = phone.replace("+91-",'');
# }
#
# FRESHCHAT_VISITORINFO={"name":name,"email":email,"phone":phone};
# </script>
#
#
# <script type='text/javascript'>
#
# //	alert("Hello");
# 	    var fc_CSS = document.createElement('link');
# 	    fc_CSS.setAttribute('rel', 'stylesheet');
# 	    var fc_isSecured = (window.location && window.location.protocol == 'https:');
# 	    var fc_lang = document.getElementsByTagName('html')[0].getAttribute('lang');
# 	    var fc_rtlLanguages = ['ar', 'he'];
# 	    var fc_rtlSuffix = (fc_rtlLanguages.indexOf(fc_lang) >= 0) ? '-rtl' : '';
# 	    fc_CSS.setAttribute('type', 'text/css');
# 	    fc_CSS.setAttribute('href', ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets1.chat.freshdesk.com') + '/css/visitor' + fc_rtlSuffix + '.css');
# 	    document.getElementsByTagName('head')[0].appendChild(fc_CSS);
# 	    var fc_JS = document.createElement('script');
# 	    fc_JS.type = 'text/javascript';
# 	    fc_JS.defer = true;
# 	    fc_JS.src = ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets.chat.freshdesk.com') + '/js/visitor.js';
# 	    (document.body ? document.body : document.getElementsByTagName('head')[0]).appendChild(fc_JS);
# 	    window.freshchat_setting = '...';
#
# </script>
#
#
# <script type='text/javascript'>
#
# if(document.getElementById("chat-widget") != undefined){
# document.getElementById("chat-widget").addEventListener("click", function(event){
#     event.preventDefault()
# });
# }
# </script>
#
# <script type="text/javascript">
# 		$(function(){
# 			$('.nav-search').click(function(e){
# 				$('.common-search').slideToggle();
# 			});
# 			 $('.dropdown-button').dropdown({
# 				  inDuration: 300,
# 				  outDuration: 225,
# 				  constrainWidth: false,
# 				  hover: true,
# 				  gutter: 0,
# 				  belowOrigin: false,
# 				  alignment: 'left',
# 				  stopPropagation: false
# 			}
# 		  );
# 		});
# 	</script>
# <script>
# 	jQuery(function() {
# 		//bottom banner starts
# 		jQuery('.bot-bnr').append('<span class="up-dwn-arrow"></span><span class="bot-bnr-cls"></span>');
# 		jQuery('.bot-bnr').addClass('bot-bnr-expnd',1000);
# 		setTimeout(function(){
# 		jQuery('.bot-bnr').removeClass('bot-bnr-expnd',1000);}, 5000);
# 		jQuery('.bot-bnr-cls').on("click", function() {
# 		  jQuery(this).parent("div").addClass('bot-bnr-csl',1000);
# 		});
# 		jQuery('.up-dwn-arrow').on("click", function() {
# 		  jQuery(this).parent("div").toggleClass('bot-bnr-expnd',1000);
# 		});
# 		//bottom banner ends
# 	});
# </script>
#
# 				<!-- Header Ends -->
#
# 				<!-- Content Starts   -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="ubility-wrap clearfix">
#     <!--Cluster related page inclusion start here-->
#
# 	<!--Cluster related page inclusion end here-->
#   <section class="ubility-lhs clearfix">
#
# <div id="search-result-cluster" class="inside-lhs">
# 	<div class="wht-bdr-bx tj-cluster">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <h4><i class="material-icons">sort</i>Refined By</h4>
# <!--  <div id="clusterRefineHistoryId"></div>-->
#
#
#
#
#
#
# <!--
#   <ul class="tab-filter clearfix">
#
#       <li class="tab-tc" id="tab-tc"><a href="#tabtc">Top Companies</a></li>
#
#
#     <li class="tab-jf" id="tab-jf"><a href="#tabjf">Job Function</a></li>
#
#
#
#       <li class="tab-ind" id="tab-ind"><a href="#tabind">Industry</a></li>
#
#
#
#
#       <li class="tab-sal" id="tab-sal"><a href="#tabsal">Salary</a></li>
#
#   </ul>
# -->
#
#   <div id="tj-tab-container-clusterId">
#     <div id="clusterDataInitial">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	<ul class="collapsible" data-collapsible="expandable">
#
#
#   <li id="tabtc">
#
#
# 	  <div class="collapsible-header active"><h6>Companies</h6></div>
#     <div class="cluster-scroll collapsible-body">
#       <ul>
#         <div id="comp_show">
#
#
#
#
#             <li>
#
#
#
#
#
#
#
#                 <input id="com_0" type="checkbox" name="topCompanies"   onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&refineBy=dateWise&from=undo&actualTxtKeywords=python&searchBy=0&rdoOperator=OR&luceneResultSize=25&postWeek=60&txtKeywords=python&cboWorkExp1=15&undokey=compCluster&compCluster=hp+enterprise+services&gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&refineBy=dateWise&from=undo&actualTxtKeywords=python&searchBy=0&rdoOperator=OR&luceneResultSize=25&postWeek=60&txtKeywords=python&cboWorkExp1=15&undokey=compCluster&compCluster=hp+enterprise+services&gadLink=View Jobs By This Company','Hp Enterprise Services');">
# 				<label for="com_0">
#                 <span title="Hp Enterprise Services">
#                 Hp Enterprise Services
#                 </span> <span class="grey-text">(30)</span></label>
#             </li>
#
#
#
#             <li>
#
#
#
#
#
#
#
# ...
#
#
#
#
# <!-- New google pixel by sokrati -->
# <!-- Global site tag (gtag.js) - Google Ads: 1067146772 -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=AW-1067146772"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'AW-1067146772');
# </script>
#
# <!-- New google pixel by sokrati -->
#
#
#
#
# <script>
# 	var parameter="";
# 	var regFlow="";
# 	var loginFlow="";
# 	var applyFlow="";
#
# 	regFlow="false";
# 	loginFlow="false";
# 	applyFlow="false";
#
# 	if(regFlow=="true")
# 	{
# 		parameter="_registrationFlow";
# 		ajaxController.trackCounter(parameter, "reg_3p9901_exp");
# 	}
# 	else if(loginFlow=="true"){
# 		var login = new RegExp("login.html", "i");
# 		if(!login.test(window.top.location) ){
# 			parameter="_loginFlow";
# 			ajaxController.trackCounter(parameter, "login_3p9901_exp");
# 		}
# 	}
#
# 	if(applyFlow=="true"){
# 		parameter="_applyFlow";
# 		ajaxController.trackCounter(parameter, "apply_3p9901_exp");
# 	}
# </script>
#
#
# <script type="text/javascript" src="//connect.facebook.net/en_US/sdk.js"></script>
#
#
#
# 	<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/fb_auto_connect.js?v=7.1.7"></script>
#
#
#
#
#
#
#
#
#
#
# <!-- Columbia AdTech(TIL) Code start Here -->
# <script type='text/javascript'>
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://static.clmbtech.com/ase/2320/34/aa.js';
#          var x = document.getElementsByTagName('script')[0];
#          x.parentNode.insertBefore(s, x);
#     })();
# </script>
# <!-- Columbia AdTech(TIL) Code end Here -->
#
# <script type='text/javascript'>
# 	function freshWidgetCallback(){
# 		FreshWidget.init("", {"queryString": "&widgetType=popup&captcha=yes&searchArea=no", "backgroundImage": "https://www.ceoconnect.in/feedback/images/tj_feedback.gif", "utf8": "?", "widgetType": "popup", "buttonType": "image", "buttonText": "Support", "buttonColor": "black", "buttonBg": "#b8eaff", "alignment": "2", "offset": "145px", "formHeight": "500px", "captcha": "yes", "url": "https://timesjobs.freshdesk.com"} );
# 	}
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://assets.freshdesk.com/widget/freshwidget.js';
#          var x = document.getElementsByTagName('script')[0];
#          // most browsers
# 		s.onload = freshWidgetCallback;
# 		// IE 6 & 7
# 		s.onreadystatechange = function() {
# 			if (this.readyState == 'complete') {
# 				freshWidgetCallback();
# 			}
# 		}
#          x.parentNode.insertBefore(s, x);
#     })();
# </script>
#
# <!-- Facebook Pixel Code -->
# <script>
# !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '1727549374127582'); // Insert your pixel ID here.
# fbq('track', 'PageView');
#
# </script>
# <noscript><img height="1" width="1" style="display:none"
# src="https://www.facebook.com/tr?id=1727549374127582&ev=PageView&noscript=1"
# /></noscript>
# <!-- End Facebook Pixel Code -->
# 				<!-- Footer Ends   -->
#
#
#
#
#
# 	<script type="text/javascript">
#         var GB_ROOT_DIR = "/candidate/greybox/";
#     </script>
#
#
# 	<link href="https://static.timesjobs.com/newtj_css/css/tj_css/personlisation/gb_styles.css" rel="stylesheet" type="text/css" media="all"/>
#
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/groupJs/searchResultTempGroup.js?v=7.1.7"></script>
#
#
#
#
# 		<script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
#           <!--[if IE]><script src="https://static.timesjobs.com/newtj_js/scripts/html5.js"></script><![endif]-->
#
#
# <script type='text/javascript'>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6036484" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
#
#   function trackAjaxSRPresult(url, type) {
# 		var title = document.getElementsByTagName("title")[0].innerHTML;
# 		title = title.replace("TimesJobs.com", type + " Jobs");
# 		title = title.concat(" | TimesJobs.com");
#
# 		var t = "2", n = "6036484", r = "", i = encodeURIComponent(url), s = "", o = "", u = encodeURIComponent(title), a = "", f = "2.0", l = "1";
# 		var c = document.createElement("img");
# 		c.src = "https://sb.scorecardresearch.com/p?c1=" + t + "&c2=" + n +"&c3=" + r + "&c4=" + i + "&c5=" + s + "&c6=" + o + "&c8=" + u + "&c15=" + a + "&cv=" + f + "&cj=" + l + "&ns__t=" + (new Date).getTime();
# 		document.body.appendChild(c);
# 	}
#
#
# </script>
#
# <noscript>
#   <img src="https://sb.scorecardresearch.com/p?c1=2&c2=6036484&cv=2.0&cj=1" />
# </noscript>
#
# <script type='text/javascript'>
# /*!
# * jQuery Cookie Plugin v1.3.1
# * https://github.com/carhartl/jquery-cookie
# *
# * Copyright 2013 Klaus Hartl
# * Released under the MIT license
# */
# (function (factory) {
# if (typeof define === 'function' && define.amd && define.amd.jQuery) {
# // AMD. Register as anonymous module.
# define(['jquery'], factory);
# } else {
# // Browser globals.
# factory(jQuery);
# }
# }(function ($) {
#
# var pluses = /\+/g;
#
# function raw(s) {
# return s;
# }
#
# function decoded(s) {
# return decodeURIComponent(s.replace(pluses, ' '));
# }
#
# function converted(s) {
# if (s.indexOf('"') === 0) {
# // This is a quoted cookie as according to RFC2068, unescape
# s = s.slice(1, -1).replace(/\\"/g, '"').replace(/\\\\/g, '\\');
# }
# try {
# return config.json ? JSON.parse(s) : s;
# } catch(er) {}
# }
#
# var config = $.cookie = function (key, value, options) {
#
# // write
# if (value !== undefined) {
# options = $.extend({}, config.defaults, options);
#
# if (typeof options.expires === 'number') {
# var days = options.expires, t = options.expires = new Date();
# t.setDate(t.getDate() + days);
# }
#
# value = config.json ? JSON.stringify(value) : String(value);
#
# return (document.cookie = [
# encodeURIComponent(key), '=', config.raw ? value : encodeURIComponent(value),
# options.expires ? '; expires=' + options.expires.toUTCString() : '', // use expires attribute, max-age is not supported by IE
# options.path ? '; path=' + options.path : '',
# options.domain ? '; domain=' + options.domain : '',
# options.secure ? '; secure' : ''
# ].join(''));
# }
#
# // read
# var decode = config.raw ? raw : decoded;
# var cookies = document.cookie.split('; ');
# var result = key ? undefined : {};
# for (var i = 0, l = cookies.length; i < l; i++) {
# var parts = cookies[i].split('=');
# var name = decode(parts.shift());
# var cookie = decode(parts.join('='));
#
# if (key && key === name) {
# result = converted(cookie);
# break;
# }
#
# if (!key) {
# result[name] = converted(cookie);
# }
# }
#
# return result;
# };
#
# config.defaults = {};
#
# $.removeCookie = function (key, options) {
# if ($.cookie(key) !== undefined) {
# $.cookie(key, '', $.extend(options, { expires: -1 }));
# return true;
# }
# return false;
# };
#
# }));
# </script>
#
# <script type='text/javascript'>
# 	jQuery.cookie('previous_browser_url', $.cookie('current_browser_url'));
# 	jQuery.cookie('current_browser_url', window.location.href);
# 	//setCookie('previous_browser_url',getCookie('current_browser_url'));
# 	//setCookie('current_browser_url', window.location.href);
# </script>
# 	<script type="text/javascript">
# 	function getPredefinedActionName(url){
# 		var returnActionName = "";
# 		var from = url.lastIndexOf("/");
# 		var to = url.indexOf("?",from);
# 		if(-1!=to){
# 			returnActionName = url.substring(from,to);
# 		}else{
# 			returnActionName = url.substring(from);
# 		}
# 		return returnActionName;
# 	}
# 	</script>
#
#
#
#
# <script type="text/javascript">
#
# var notification_timeout = 10000;
# var notification_cache = true;
# function ping(url){
#  var ImageObject = new Image();
#  ImageObject.src = url; //e.g. logo
# }
# var cand_context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  cand_context="/candidate/";
# 		  //alert("bingo");
# 	}
#
# 		function getMailInBoxUnreadCount(){
# 			var rurl=cand_context+"inbox-message-get-unread-count.html";
# 			jQuery.ajax({
# 				cache:notification_cache,
# 				url:rurl,
# 				success:function(data){
# 					console.log("success... inbox-message-get-unread-count.html"+'');
# 				},
# 				error: function(x, textStatus, m) {
# 					console.log("Failed"+m);
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            //do something. Try again perhaps?
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    	}
# 			});
# 		}
#
# 		function getDistinctEmployerCounts(){
# 		 var rurl=cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_RE";
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:rurl,
# 			success:function(data){
# 				//alert("RE-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_re").html(data);
# 				jQuery("#mytj_header_re").html(data);
# 				jQuery("#homeindex_inbox_re").html(data);
# 				jQuery("#headerhome_inbox_re").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			            console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			            //do something. Try again perhaps?
# 			        }
# 		    }
#
# 		});
# 	//alert("call in progress...");
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV",
# 			success:function(data){
# 				//alert("PV-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_pv").html(data);
# 				jQuery("#mytj_header_pv").html(data);
# 				jQuery("#homeindex_inbox_pv").html(data);
# 				jQuery("#headerhome_inbox_pv").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV"+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    }
# 		});
# 	 }
# 	function displayLoading(div){
# 	if(1 == tab || 2 == tab || 4 == tab || 5 == tab  ){
# 			jQuery(div).append("<div class='loading'>&nbsp;</div>");
# 	}
# }
# </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "location": {
#     "@type": "Place",
#     "address": "TimesJobs.com, Times Business Solutions (A Division of Times Internet Ltd.), Times Center (Digital Content Production Facility), FC - 6, (Ground Floor), Sector 16 A, Film City, NOIDA - 201 301, Uttar Pradesh, India"
#   },
#   "name": "TimesJobs.com",
#   "description": "TimesJobs: India's Leading Job Portal",
#   "logo": "https://static.timesjobs.com/images_cand/tj_images/logos/tj_logo_300x300.jpg",
#   "url": "https://www.timesjobs.com",
#   "email": "timesjobs@timesgroup.com"
# }
# </script>
# <script type="application/ld+json">
# {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "https://www.timesjobs.com",
#     "potentialAction": {
#       "@type": "SearchAction",
#       "target": "https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords={search_term_string}",
#       "query-input": "required name=search_term_string"
#     }
# }
# </script>
# 	<!--Common Template Included in all files end here  -->
# 	<!--google analytics start-->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# 	var _gaq = _gaq || [];
#
#
#
#
#
#
#
#
# 			_gaq.push(['_setAccount', 'UA-1688637-1']);
#
#
#   _gaq.push(['_trackPageview']);
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
#   function trackClickEvent(category,action){
# 		_gaq.push(['_trackEvent',category,action]);
# 	}
# </script>
# 	<!--google analytics ends-->
#
# 		<img src="https://tracking.sokrati.com/site?client_id=60&product_category=Site_Search" height="1" width="1" border="0" alt="" />
#
#
# <script type='text/javascript'>
#
# 	function removeSpecificRefineNew(urltoHit){
#  	getSRPResultByDwrNew(urltoHit);
#  	return false;
#  }
#
#  function getSRPResultByDwrNew(urlToHit) {
# 		jQuery( "#refine-opt-search-datewise a" ).removeClass( "refinejobsopt" );
# 		jQuery("#defualtSelectedDate").addClass( "refinejobsopt" );
# 		jQuery("#searchResultData").remove();
# 		jQuery("#searchResultContents").html(dataImageLoader);
# 		var matchStr=urlToHit.match("&undo=(.*)&undoValue");//For Selecting tab on Cluster
#
# 		ajaxController.getDWRBasedWebResponse(urlToHit,function(data) {
# 							if (data != null && data != 'undefined') {
# 								jQuery("#searchResultContents").html(data);
#
# 								console.info("matchStr=="+matchStr);
# 								if(chkNull(matchStr)){
# 									console.info("matched text at posotion 1="+matchStr[1]);
# 									showSelectedTabData(matchStr[1]);
# 								}
# 								if(matchStr==null && urlToHit.indexOf("undo=")!=-1){
# 									//jQuery( ".refined-bx" ).tabs("refresh");
#
# 								}
# 								//For making initial tab selected
# 								if(urlToHit.indexOf("&reset")!=-1){
# 									console.info("inside reset all tab");
# 									//jQuery( ".refined-bx" ).tabs("refresh");
# 								}
# 							} else {
# 								jQuery("#searchResultContents").html("Oops! There seems to be a technical problem. Please try again");
# 							}
# 						});
# 						return false;
# 	}
#
#
#
# 	if (top != self){
# 		window.open(self.location.href,"_top");
# 	}
# 	var siteId='1040';
# 	var stype = 'timesjobs.com';
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://ceoconnect.in/feedback/scripts/feedbackInc.js';
#          var x = document.getElementsByTagName('script')[0];
#          x.parentNode.insertBefore(s, x);
#     })();
# </script>
# 		</div>
#
# <script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/lightBox.js"></script>
# <div id="light-box-popup" class="modal">
# 	<span class="material-icons close-modal modal-action modal-close">close</span>
# 	<div class="modal-content" id="light-box-popup-content"></div>
# </div>
# <!-- <script type="text/javascript">
#   $(document).ready(function(){
# 	    // the "href" attribute of the modal trigger must specify the modal ID that wants to be triggered
# 	    $('.modal').modal();
# 	  });
#
#   </script> -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	<!--  ##########################  JobBuzz Ads  ################## -->
#
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"applicationID":"96890711","applicationTime":315,"beacon":"bam-cell.nr-data.net","queueTime":0,"licenseKey":"2a67c1bd6d","transactionName":"NgdTbUEHV0JYBUZYWQ9Ne2pjSW50e0t7f3BOCEJJHBNKUFsPXlhCGE1FXF4WVVBNAx1SVw8GWF1SElxiXAdAUl4TB0JMXxJtVFQWXlBCBExbSkM=","agent":"","errorBeacon":"bam-cell.nr-data.net"}</script></body>
# </html>

# %%
# parse HTML text
soup = BeautifulSoup(html_text, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).loader_config={licenseKey:"2a67c1bd6d",applicationID:"96890711"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n){return function(){return o(t,[u.now()].concat(f(arguments)),e?null:this,n),e?void 0:this}}var o=t("handle"),a=t(8),f=t(9),c=t("ee").get("tracer"),u=t("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var d=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],p="api-",l=p+"ixn-";a(d,function(t,e){s[e]=i(p+e,!0,"api")}),s.addPageAction=i(p+"addPageAction",!0),s.setCurrentRouteName=i(p+"routeName",!0),e.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(t,e){var n={},r=this,i="function"==typeof e;return o(l+"tracer",[u.now(),t,n],r),function(){if(c.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return e.apply(this,arguments)}catch(t){throw c.emit("fn-err",[arguments,this,t],n),t}finally{c.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(t,e){m[e]=i(l+e)}),newrelic.noticeError=function(t,e){"string"==typeof t&&(t=new Error(t)),o("err",[t,u.now(),!1,e])}},{}],2:[function(t,e,n){function r(t){if(NREUM.init){for(var e=NREUM.init,n=t.split("."),r=0;r<n.length-1;r++)if(e=e[n[r]],"object"!=typeof e)return;return e=e[n[n.length-1]]}}e.exports={getConfiguration:r}},{}],3:[function(t,e,n){function r(){return f.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,f=t(10);e.exports=r,e.exports.offset=a,e.exports.getLastTimestamp=i},{}],4:[function(t,e,n){function r(t){return!(!t||!t.protocol||"file:"===t.protocol)}e.exports=r},{}],5:[function(t,e,n){function r(t,e){var n=t.getEntries();n.forEach(function(t){"first-paint"===t.name?d("timing",["fp",Math.floor(t.startTime)]):"first-contentful-paint"===t.name&&d("timing",["fcp",Math.floor(t.startTime)])})}function i(t,e){var n=t.getEntries();n.length>0&&d("lcp",[n[n.length-1]])}function o(t){t.getEntries().forEach(function(t){t.hadRecentInput||d("cls",[t])})}function a(t){if(t instanceof m&&!g){var e=Math.round(t.timeStamp),n={type:t.type};e<=p.now()?n.fid=p.now()-e:e>p.offset&&e<=Date.now()?(e-=p.offset,n.fid=p.now()-e):e=p.now(),g=!0,d("timing",["fi",e,n])}}function f(t){"hidden"===t&&d("pageHide",[p.now()])}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var c,u,s,d=t("handle"),p=t("loader"),l=t(7),m=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){c=new PerformanceObserver(r);try{c.observe({entryTypes:["paint"]})}catch(v){}u=new PerformanceObserver(i);try{u.observe({entryTypes:["largest-contentful-paint"]})}catch(v){}s=new PerformanceObserver(o);try{s.observe({type:"layout-shift",buffered:!0})}catch(v){}}if("addEventListener"in document){var g=!1,h=["click","keydown","mousedown","pointerdown","touchstart"];h.forEach(function(t){document.addEventListener(t,a,!1)})}l(f)}},{}],6:[function(t,e,n){function r(t,e){if(!i)return!1;if(t!==i)return!1;if(!e)return!0;if(!o)return!1;for(var n=o.split("."),r=e.split("."),a=0;a<r.length;a++)if(r[a]!==n[a])return!1;return!0}var i=null,o=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var f=navigator.userAgent,c=f.match(a);c&&f.indexOf("Chrome")===-1&&f.indexOf("Chromium")===-1&&(i="Safari",o=c[1])}e.exports={agent:i,version:o,match:r}},{}],7:[function(t,e,n){function r(t){function e(){t(a&&document[a]?document[a]:document[i]?"hidden":"visible")}"addEventListener"in document&&o&&docu ...
#   </script>
#   <link href="https://fonts.googleapis.com/css?family=Poppins:400,500,600,700" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
#   <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
#   <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js" type="text/javascript">
#   </script>
#   <!-- <script type="text/javascript" src="https://code.angularjs.org/1.7.0/angular.min.js"></script> -->
#   <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/angular1.7.0.min.js" type="text/javascript">
#   </script>
#   <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/materialize.min.js" type="text/javascript">
#   </script>
#   <script src="https://static.timesjobs.com/newtj_js/scripts/groupJs/dwrGroup.js?v=7.1.7" type="text/javascript">
#   </script>
#   <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/mustache.js" type="text/javascript">
#   </script>
#   <link href="https://www.timesjobs.com/candidate/job-search.html" rel="canonical"/>
#   <link href="https://www.timesjobs.com/candidate/job-search.html?from=submit&amp;txtKeywords=python&amp;cboWorkExp1=15/&amp;sequence=2&amp;startPage=1" rel="next"/>
#   <title>
#    python Jobs with 15 years experience - TimesJobs
#   </title>
#   <meta content="Jobs in python with 15 years experience. Search and apply jobs online at Timesjobs.com" name="description"/>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-59SJDG4');
#   </script>
#   <!-- End Google Tag Manager -->
#   <script src="https://www.gstatic.com/charts/loader.js" type="text/javascript">
#   </script>
#   <script>
#    //google.charts.load('current', {'packages':['bar']});
#           google.charts.load('current', {packages: ['corechart', 'bar']});
#   </script>
#  </head>
#  <body>
#   <div id="site">
#    <!-- Header Starts -->
#    <!-- Google Tag Manager (noscript) -->
#    <noscript>
#     <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-59SJDG4" style="display:none;visibility:hidden" width="0">
#     </iframe>
#    </noscript>
#    <!-- End Google Tag Manager (noscript) -->
#    <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#    <!--[if IE]>
# <script src="scripts/html5shiv.js"></script>
# <![endif]-->
#    <script src="https://static.timesjobs.com/newtj_js/scripts/ajax-upload.js" type="text/javascript">
#    </script>
#    <div class="msg notify" id="fb_connect_suggest" style="display: none;">
#     Dear Jobseeker, Find millions of jobs on single click.
#     <span id="fb_auto_connect">
#      <a href="javascript:fconnect_auto();">
#       <img alt="fconnect" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/top-facebook-notify.png"/>
#      </a>
#     </span>
#     <span class="big-cls cls-icn" onclick="javascript:ack_fbconnect_cancel();" title="Click to Hide">
#      <i class="material-icons">
#       close
#      </i>
#     </span>
#     <span id="fb_connect_status">
#     </span>
#    </div>
#    <div class="msg success" id="fb_connect_success" style="display: none;">
#     Congratulations! You have been logged in via Facebook
#    </div>
#    <header class="main-header">
#     <div class="top-header">
#      <div class="ubility-wrap clearfix">
#       <ul class="top-link">
#        <li>
#         <a class="link-active" href="https://www.timesjobs.com">
#          TimesJobs
#         </a>
#        </li>
#        <li>
#         <a href="http://jobbuzz.timesjobs.com" target="_blank">
#          JobBuzz
#         </a>
#        </li>
#        <!--<li><a href="http://stepahead.timesjobs.com" target="_blank">Career Services</a></li>
#      <li><a href="http://www.techgig.com" target="_blank">TechGig</a></li> -->
#        <li>
#         <a href="https://ae.timesjobs.com" target="_blank">
#          Gulf Jobs
#         </a>
#        </li>
#        <li>
#         <a href="http://content.timesjobs.com/recruitex?fromsite=tjcand" target="_blank">
#          Career Insight
#         </a>
#        </li>
#       </ul>
#       <ul class="top-contact">
#        <li>
#         <i class="material-icons">
#          call
#         </i>
#         0120 6358222
#        </li>
#        <li>
#         <span class="live-chat" id="chat-widget">
#          Live Chat (10am to 6pm IST)
#         </span>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="ubility-wrap logo-section clearfix">
#      <a class="top-tj-logo" href="https://www.timesjobs.com" itemprop="url" title="TIMESJOBS">
#       <img alt="TimesJobs" height="23" itemprop="logo" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/tj-logo-new.png" title="TimesJobs" width="140"/>
#      </a>
#      <div class="career-affection top-notifi notify-msg covid-home-page" id="career-affection" style="display:none">
#       <div class="career-affection-inner wrap career-effect" id="career-affection-inner ">
#        Is your career affected by Covid-19?
#        <a class="yes-button" href="javascript:void(0);" onclick="profilePreview.covidAffectedProfile('Y','TJWEB');">
#         Yes
#        </a>
#        <a class="no-button" href="javascript:void(0);" onclick="profilePreview.covidAffectedProfile('N','TJWEB');">
#         No
#        </a>
#       </div>
#      </div>
#      <script type="text/javascript">
#       jQuery(document).ready(function() {
# 					jQuery("#career-affection").show();
# 					jQuery("#career-affection-rhs").show();
# 				})
#      </script>
#      <ul class="main-tj-nav clearfix">
#       <script type="text/javascript">
#        var notification_timeout = 10000;
# var notification_cache = true;
# if (!window.console) console = {log: function() {}};
#
# if(typeof String.prototype.trim !== 'function') {
#   String.prototype.trim = function() {
#     return this.replace(/^\s+|\s+$/g, '');
#   }
# }
#
#
# /* This function is used to set cookies */
# function setCookie(name,value,expires,path,domain,secure) {
#   document.cookie = name + "=" + escape (value) +
#     ((expires) ? "; expires=" + expires.toGMTString() : "") +
#     ((path) ? "; path=" + path : "") +
#     ((domain) ? "; domain=" + domain : "") + ((secure) ? "; secure" : "");
# }
#
# /* This function is used to get cookies */
# function getCookie(name) {
# 	var prefix = name + "=" ;
# 	var start = document.cookie.indexOf(prefix);
#
# 	if (start==-1) {
# 		return null;
# 	}
#
# 	var end = document.cookie.indexOf(";", start+prefix.length);
# 	if (end==-1) {
# 		end=document.cookie.length;
# 	}
#
# 	var value=document.cookie.substring(start+prefix.length, end) ;
# 	return unescape(value);
# }
#
#
# function deleteCookie(name,path,domain) {
#   if (getCookie(name)) {
#     document.cookie = name + "=" +
#       ((path) ? "; path=" + path : "") +
#       ((domain) ? "; domain=" + domain : "") +
#       "; expires=Thu, 01-Jan-70 00:00:01 GMT";
#   }
# }
#
# var authenticated = 'false';
#
# jQuery(document).ready(function(){
# var alreadyCalled = false;
#
# //alert("logged-in:"+authenticated);
# //alert("comparison to true, for"+authenticated +", "+ ('true' == authenticated));
#
# if('true' == authenticated){
# 	//jQuery(".viewnoteTab").mouseout(function(){
# //	  jQuery(".showdiv").hide();
# //	});
# //	jQuery(".viewnoteTab").mouseenter(function(){
# //	  jQuery(".showdiv").show();
# //	});
# 	//alert("logged in ");
# }else{
# 	//alert("not logged in ");
# 	jQuery(".notif-cls").on("click",function(){
# 		//alert('hi');
# 	  jQuery("#inline_login").hide();
# 	  //jQuery(".notification .nav-drop").hide();
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# 	updateNonLoggedInUsersTime();
# }
# function updateNonLoggedInUsersTime(){
# 	//alert("non_loggedin_time:"+getCookie('non_loggedin_time'));
# 	var setCookieForTime = getCookie('non_loggedin_time');
# 	if(null!=setCookieForTime){
# 		//alert("cookie found to be set to : "+setCookieForTime+" where time since is:"+timeSince(setCookieForTime));
# 		jQuery("#non_loggedin_time").html(timeSince(setCookieForTime));
# 	}else{
# 		var currentTime = new Date().getTime();
# 		setCookie('non_loggedin_time',currentTime);
# 	}
# }
#
# jQuery(".viewnote").on("click",function(){
# 	var loggedInClicked = getCookie('loggedin_click');
# 	if(null!=loggedInClicked){
# 		jQuery("#notification_count").css("background-color","#075DC1");
# 	}else{
# 		if('true' == authenticated){
# 			setCookie('loggedin_click',1);
# 			//alert("setting loggedInClicked");
# 		}
# 	}
# });
#
# });
#       </script>
#       <!--- view notification section begin --->
#       <li class="notification viewnote">
#        <a class="dropdown-button" data-activates="notifyDropdown" href="#">
#         <i class="material-icons left">
#          notifications_none
#         </i>
#         <span class="notif-count-new" id="notification_count">
#          1
#         </span>
#        </a>
#        <div class="nav-drop viewnoteTab dropdown-content" id="notifyDropdown">
#         <div class="showdiv">
#          <div class="notif-not-logedin" id="non_loggedin" style="display:none;">
#           <div class="notif-welcm-msg clearfix">
#            To see all recommended jobs, profile views, recruiter's contacted information, updates and more...
#           </div>
#           <div class="notif-act clearfix">
#            <button class="waves-effect waves-light btn red-bdr-btn" onclick="javascript:openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');" type="button">
#             Login
#            </button>
#            <strong class="or">
#             or
#            </strong>
#            <a class="waves-effect waves-light btn red-bdr-btn" href="/candidate/register.html">
#             Register
#            </a>
#           </div>
#          </div>
#          <!-- INLINE LOGIN PAGE -->
#          <div class="notif-login-frm" id="inline_login" style="display:none;">
#           <span class="notif-cls" title="Click to Hide">
#           </span>
#           <strong>
#            Login to View Notifications!
#           </strong>
#           <form action="/candidate/times_login?BeforeLoginUrl=notification&amp;tab=1" method="post" name="loginFormNotification">
#            <input class="txt2 defaultValue inpt-typ" id="txtUseNameNotification" name="j_username" onblur="javascript:settextNotification('txtUseNameNotification');" onclick="filltxtNotification(txtUseNameNotification)" size="42" type="text" value="Enter Email id / Login id"/>
#            <input class="password_input_notification" name="j_password" size="42" style="display:none" type="password" value=""/>
#            <input class="clearNotification" size="42" type="text" value="Enter Password"/>
#            <div class="frgt-pass">
#             <a class="fp" href="javascript:forgotPasswordNotification();">
#              Forgot Password?
#             </a>
#            </div>
#            <input class="" onclick="javascript:return validateLoginFormNotification();" type="submit" value="Login"/>
#            <div class="error-msg dflt-msg" id="loginErrNotification" style="display:none;">
#             <!--<img class="errTip" title="Error" alt="Error" src="https://static.timesjobs.com/images_cand/tj_images/home/errTipL.gif">-->
#             <!--<a class="errCls" href="#"><img border="0" title="Close" alt="Close" src="/images_cand/tj_images/home/logginErrClse.gif"></a>-->
#             Login-ID/Password cannot be left blank. Enter the full email ID (like: ram@gmail.com), if you are using registered email-id for login.
#            </div>
#            <input name="notlogin" type="hidden" value="mytj"/>
#            <input name="_acegi_security_remember_me" type="hidden" value="yes"/>
#           </form>
#          </div>
#          <!-- INLINE LOGIN PAGE -->
#          <div class="notif-main" id="base" style="display: none;">
#           <ul>
#            <li class="heading clearfix" id="heading">
#             <a href="#" id="heading-link">
#              <span>
#               Job Alerts(10)
#              </span>
#             </a>
#            </li>
#            <li id="base-li" style="display: none;">
#             <a href="#" id="base-li-anchor">
#              5 Matching Jobs
#              <span id="base-li-time">
#               3 hrs ago
#              </span>
#             </a>
#            </li>
#            <span class="base_li" id="base-li-data" style="display: none;">
#            </span>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </li>
#       <!--- view notification section ends here --->
#       <script type="text/javascript">
#        function forgotPasswordNotification(){
# 		GB_showCenter('Forgot Password','/candidate/ForgetPassword.html',180,420);
# 	}
# var race = 0;
# function showNotificationLoginThickBox(){
#
# race = 1;
#
# 			//jQuery("#inline_login").addClass('notifyshow');
# 			//jQuery('.viewnoteTab').addClass('notifyshow');
# 			//jQuery('.showdiv').addClass('notifyshow');
# 			//jQuery(".notif-not-logedin").hide();
# 			//jQuery(".notification .nav-drop").css('display','block');
# 			//jQuery(".notification").addClass("notifi");
# 			jQuery('.clearNotification').css({color:"#b3b3b3"});
# 					jQuery('.clearNotification').focus(function(){
# 						//alert('check');
# 						jQuery(this).hide();
# 						jQuery(' .password_input_notification').show();
# 						jQuery('.password_input_notification').focus();
# 					});
# 					jQuery('.password_input_notification').blur(function(){
# 						if(this.value==''){
# 						jQuery(this).hide();
# 							jQuery('.clearNotification').show();
# 						}
# 					});
#
#
#
# }
# jQuery(".notif-cls").on("click",function(){
# 	  //jQuery("#inline_login").removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.viewnoteTab').removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.showdiv').removeClass('notifyshow');
#
# 	 // jQuery(".notif-not-logedin").show();
# 	 jQuery(".notif-not-logedin").css('display','');
# 	  //jQuery(".notification .nav-drop").css('display','none');
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# jQuery(".viewnote").mouseenter(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").show();
#   //jQuery(".notification .nav-drop").show();
#
#   if('false' == authenticated){
#     var hideCountCookie = getCookie('hide_nologgedin_count');
#     if(null == hideCountCookie){
#   		setCookie('hide_nologgedin_count',1);
#   		//alert("setting hide_nologgedin_count");
#   	}else{
#   		jQuery("#notification_count").hide();
#   	}
#   }else{
#    jQuery("#inline_login").hide();
#    jQuery("#non_loggedin").hide();
#
#    	updateNotificationComponentWithIECheck();
#   }
#
# });
# jQuery(".viewnote").mouseleave(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").hide();
#   //jQuery(".notification .nav-drop").hide();
# });
# jQuery(".notif-login-frm").mouseleave(function(){
# //alert("mouseenter called..");
#   event.stopPropagation()
# });
# function settextNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value !=''){
# 			document.getElementById(id).checked=true;
# 		}else{
# 			document.getElementById(id).checked=false;
# 			document.getElementById('txtUseNameNotification').value='Enter Email id / Login id';
# 			document.getElementById('txtUseNameNotification').style.color='#999'
# 		}
# 	}
# function filltxtNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id')
# 			document.getElementById('txtUseNameNotification').value=''
# 		document.getElementById('txtUseNameNotification').style.color='#333'
# 	}
# function validateLoginFormNotification(){
# var status = true;
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id'){
# 			document.getElementById('txtUseNameNotification').value='';
# 			status =  false;
# 		}
#
# 		if(checkBlankNotification(document.loginFormNotification.j_username,"Login ID")){
# 			status =  false;
# 		}
# 		if(checkBlankNotification(document.loginFormNotification.j_password,"Password")){
# 			status =  false;
# 		}
# 		//update_notification_cookie
# 		if(status){
# 			deleteCookie('update_notification_cookie');
# 		}
# 		return status;
# 	}
# function checkBlankNotification(field,name){
# 		if(field.value.trim() == ""){
# 			field.value = "";
# 			field.focus();
# 			document.getElementById("loginErrNotification").style.display="";
# 			return true;
# 		}
# 		return false;
# 	}
#
# var diff = 1627013549-((new Date().getTime())/1000);
#
#
# function ellipsize(str, len) {
# 	if(str.length > len) {
#  		return str.substr(0,len) + "...";
# 	} else {
# 		return str;
# 	}
# }
#
# function timeSince(previous){
#
# 	current =  new Date().getTime()+diff;
# 	var milleSecondsPerMinute = 60 * 1000;
#     var milleSecondsPerHour = milleSecondsPerMinute * 60;
#     var milleSecondsPerDay = milleSecondsPerHour * 24;
#     var milleSecondsPerMonth = milleSecondsPerDay * 30;
#     var milleSecondsPerYear = milleSecondsPerDay * 365;
#
#     var elapsed = current - previous;
#
#     if (elapsed < milleSecondsPerMinute) {
#          value = Math.round(elapsed/1000) + ' seconds ago';
#     }
#
#     else if (elapsed < milleSecondsPerHour) {
#     	value = Math.round(elapsed/milleSecondsPerMinute) + ' minutes ago';
#     }
#
#     else if (elapsed < milleSecondsPerDay ) {
#     	value = Math.round(elapsed/milleSecondsPerHour ) + ' hours ago';
#     }
#
#     else if (elapsed < milleSecondsPerMonth) {
#     	value =  Math.round(elapsed/milleSecondsPerDay) + ' days ago';
#     }
#
#     else if (elapsed < milleSecondsPerYear) {
#     	value = Math.round(elapsed/milleSecondsPerMonth) + ' months ago';
#     }
#
#     else {
#     	value = Math.round(elapsed/milleSecondsPerYear ) + ' years ago';
#     }
#     //return (value);
#     return (value);
# }
#
#
# function updateNotificationComponent(){
#  alreadyCalled  =true;
# 	var context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  context="/candidate/";
# 		  //alert("bingo");
# 	}
#
#
# 	ajaxController.getLoginId(function(response){
# 	//alert("updateNotificationComponent,response:"+response)
# 		if (response != null && response.trim().length > 0) {
# 			jQuery.ajax({
# 							cache:notification_cache,
# 							timeout:notification_timeout,
# 							url:context+"inbox-notifications.html?from=submit",
# 							success:function(data){
# 							var trimLength = 30;
# 									jQuery("#base_ja").remove();
# 									jQuery("#base_j").remove();
# 									jQuery("#base_rv").remove();
# 									//alert(data);
# 									var parsedData = JSON.parse(data);
# 									var theCount = parsedData["count"];
#
# 									var jaCount = parsedData["jaCount"];
# 									var jCount = parsedData["jCount"];
# 									var rvCount = parsedData["rvCount"];
#
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
# 									//theCount = theCount - jCount;
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
#
# 									if(theCount >= 0){
# 										if(theCount >= 0){
# 											if(theCount <99){
# 												jQuery("#notification_count").html(theCount);
# 												setCookie('notification_cookie_count',theCount);
# 											}else{
# 												jQuery("#notification_count").html("99+");
# 												setCookie('notification_cookie_count',"99+");
# 											}
# 										}
#
# 										var isNew = parsedData["new"];
# 										//alert("new:"+(isNew == true));
# 										if(isNew == true){
# 											jQuery("#notification_count").css("background-color","red");
# 											setCookie('notification_cookie_color','red');
# 											deleteCookie('loggedin_click');
# 										}else{
# 											var loggedInClicked = getCookie('loggedin_click');
# 											//alert("loggedInClicked:"+loggedInClicked);
# 											if(null!=loggedInClicked){
# 												jQuery("#notification_count").css("background-color","#075DC1");
# 												setCookie('notification_cookie_color','#075DC1');
# 											}else{
# 												jQuery("#notification_count").css("background-color","red");
# 												setCookie('notification_cookie_color','red');
# 											}
#
# 										}
# 									}
# 									jQuery("#notification_count").show();
#
# 									/* alert("count:"+parsedData["count"]);
# 									alert("jaCount:"+parsedData["jaCount"]);
# 									alert("jCount:"+parsedData["jCount"]);
# 									alert("rvCount:"+parsedData["rvCount"]); */
#
# 									/**
# 									start-JA
# 									*/
# 									if(jaCount){
# 										if(jaCount <25){
# 											jQuery("#base .heading span").html("Job alerts ("+jaCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Job alerts (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Job alerts");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jaData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jaData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jaData"])[i].subject;
# 										var since = timeSince(JSON.parse(parsedData["jaData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=1&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_ja_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_ja");
# 									//alert("jaData[0]:"+ (JSON.parse(parsedData["jaData"]).length));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-JA
# 									*/
#
# 									/**
# 									start-J
# 									*/
# 								   if(jCount){
# 									 	if(jCount <25){
# 											jQuery("#base .heading span").html("Mails from recruiters ("+jCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Mails from recruiters (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Mails from recruiters");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jData"])[i].EmployerName + " contacted you.";
# 										var since = timeSince(JSON.parse(parsedData["jData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=2&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_j_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_j");
# 									//alert("jData[0]:"+timeSince(JSON.parse(parsedData["jData"])[0].creationTime));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-J
# 									*/
#
# 									/**
# 									start-RV
# 									*/
# 									if(rvCount > 0){
# 										if(rvCount <25){
# 											jQuery("#base .heading span").html("Who's viewed your profile ("+rvCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Who's viewed your profile (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Who's viewed your profile");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["rvData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["rvData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["rvData"])[i].subject;
# 										var employerName = JSON.parse(parsedData["rvData"])[i].EmployerName + " viewed your resume.";
# 										var since = timeSince(JSON.parse(parsedData["rvData"])[i].creationTime);
# 										if(null!=employerName && employerName.length > 0){
# 											jQuery("#base-li-anchor").html(ellipsize(employerName,trimLength));
# 											jQuery("#base-li-anchor").attr("title",employerName);
# 										}else{
# 											jQuery("#base-li-anchor").html("Resume Viewed");
# 										}
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=5&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_rv_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_rv");
# 									//alert("rvData[0]:"+timeSince(JSON.parse(parsedData["rvData"])[0].employerName));
# 									jQuery("#base > ul span.base_li").html("");
# 									/**
# 									end-RV
# 									*/
#
# 									jQuery("#base").hide();
# 									jQuery("li#base-li").hide();
# 								},
# 							complete:function(){
# 								console.log("complete... inbox-notifications");
# 								jQuery("#inline_login").hide();
#    								jQuery("#non_loggedin").hide();
#    								alreadyCalled  = false;
# 							},
# 							error: function(x, t, m) {
# 								console.log("Error message"+m);
# 								 var randomnumber=Math.floor(Math.random()*100000001);
# 								 var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+context+"inbox-notifications.html?from=submit"+'&op=respTracking#'+randomnumber;
# 								 ping(nlpurl);
# 						        jQuery("#error").show();
# 							}
# 						});
#
# 		}else{
# 					jQuery("#base_ja").remove();
# 					jQuery("#base_j").remove();
# 					jQuery("#base_rv").remove();
# 					if(0 == race){
# 						jQuery("#non_loggedin").show();
# 					}
#
#
# 					var hideCountCookie = getCookie('hide_nologgedin_count');
# 					if(null != hideCountCookie){
# 						/*This is commented because for non logged in user default count 1 is being hidden.*/
# 						//jQuery("#notification_count").hide();
# 					}else{
# 						jQuery("#notification_count").css("background-color","red");
# 						jQuery("#notification_count").show();
# 					}
# 					alreadyCalled  = false;
# 		}
# 	});
# }
#
# var updateNotificationCookie = getCookie('update_notification_cookie');
# //alert("updateNotificationCookie: "+updateNotificationCookie);
# if(null == updateNotificationCookie || updateNotificationCookie==''){
# 	updateNotificationComponentWithIECheck();
# 	setCookie('update_notification_cookie',1);
# 	//alert("cookie set");
# 	scheduleNotificationCookieToDie();
# }else{
# 	if('true' == authenticated){
# 		//alert("updating from cookie!!!");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		if(null==notificationCookieCount){
# 			updateNotificationComponent();
# 		}
# 		updateNotificationFromCookie();
# 	}else{
# 		//alert("not updating from cookie!!!");
# 		updateNotificationComponentWithIECheck();
# 	}
# }
#
# function scheduleNotificationCookieToDie(){
# 	setTimeout(function() {
# 	      deleteCookie('update_notification_cookie');
# 	      deleteCookie('notification_cookie_count');
# 	      deleteCookie('notification_cookie_color');
# 	},5*60*1000);
# }
#
# function updateNotificationFromCookie(){
# console.log("cookie set for updateNotificationCookie, not making server call.");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		//alert("not setting cookie"+updateNotificationCookie);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").html(""+notificationCookieCount);
# 		}else{
# 			jQuery("#notification_count").html("1");
# 		}
# 		var notificationCookieColor = getCookie('notification_cookie_color');
# 		//alert("cookie color"+notificationCookieColor);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").css("background-color",notificationCookieColor);
# 		}else{
# 			jQuery("#notification_count").css("background-color","red");
# 		}
# 		jQuery("#notification_count").show();
# }
#
# function updateNotificationComponentWithIECheck(){
# <!--[if gte IE 9]>
# 		updateNotificationComponent();
# 	<!--<![endif]-->
# 	<!--[if lt IE 9]>
#    		jQuery(document).ready(function() {
# 			updateNotificationComponent();
# 		});
# 	<!--<![endif]-->
# }
#       </script>
#       <li class="login-reg">
#        <a href="javascript:void(0);" onclick="openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');">
#         Login
#        </a>
#       </li>
#       <li class="login-reg">
#        <a href="/candidate/register.html?pageFlow=TJ_SEARCH">
#         Register
#        </a>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <!--bottom banner starts-->
#    <!--bottom banner ends-->
#    <div class="open-search ">
#     <div class="usability-srch clearfix">
#      <div class="main-srch-form clearfix">
#       <div class="msg error" id="errorMsgDiv" style="display:none">
#        Please provide inputs for at least one field
#       </div>
#       <form action="https://www.timesjobs.com/candidate/job-search.html" id="quickSearchBean" method="get" name="quickSearchBean" onsubmit="return searchEngine.validateSearchForm(this);">
#        <input name="searchType" type="hidden" value="personalizedSearch"/>
#        <input name="from" type="hidden" value="submit"/>
#        <div class="auto-suggest-blk">
#         <input class="browser-default" id="txtKeywords" name="txtKeywords" type="text" value="python"/>
#         <div id="autoSuggestList" style="display:none;">
#          <ul>
#          </ul>
#         </div>
#         <iframe frameborder="0" id="FrameautoSuggestList" style="display:none;">
#         </iframe>
#         <div class="suggestionList srch-suggest" id="autoSuggestList2ndKeywordsListSFB" style="display:none;">
#          <h5>
#           Suggested Keywords
#          </h5>
#          <ul>
#          </ul>
#         </div>
#        </div>
#        <div class="auto-suggest-blk location-srch">
#         <input class="location-srch browser-default" id="txtLocation" name="txtLocation" type="text" value="Enter Location"/>
#         <div id="autoSuggestLocation" style="display:none;">
#          <ul>
#          </ul>
#         </div>
#         <iframe frameborder="0" id="FrameautoSuggestLocation" style="display:none">
#         </iframe>
#        </div>
#        <div class="srch-select">
#         <select class="browser-default" id="cboWorkExp1" name="cboWorkExp1">
#          <option value="-1">
#           Experience
#          </option>
#          <option value="0">
#           Entry Level
#          </option>
#          <option value="1">
#           1 year
#          </option>
#          <option value="2">
#           2 years
#          </option>
#          <option value="3">
#           3 years
#          </option>
#          <option value="4">
#           4 years
#          </option>
#          <option value="5">
#           5 years
#          </option>
#          <option value="6">
#           6 years
#          </option>
#          <option value="7">
#           7 years
#          </option>
#          <option value="8">
#           8 years
#          </option>
#          <option value="9">
#           9 years
#          </option>
#          <option value="10">
#           10 years
#          </option>
#          <option value="11">
#           11 years
#          </option>
#          <option value="12">
#           12 years
#          </option>
#          <option value="13">
#           13 years
#          </option>
#          <option value="14">
#           14 years
#          </option>
#          <option selected="selected" value="15">
#           15 years
#          </option>
#          <option value="16">
#           16 years
#          </option>
#          <option value="17">
#           17 years
#          </option>
#          <option value="18">
#           18 years
#          </option>
#          <option value="19">
#           19 years
#          </option>
#          <option value="20">
#           20 years
#          </option>
#          <option value="21">
#           20+ years
#          </option>
#         </select>
#        </div>
#        <button class="waves-effect waves-light btn" onclick="javascript:setAClickOnSearch();" value="Search">
#         Find Jobs
#        </button>
#       </form>
#      </div>
#      <div class="recent-srchs home-srchptext srch-top-right" id="recentSearchId" style="display: none;">
#      </div>
#      <div class="upload-res-uni srch-top-right clearfix" id="resNewUpload" style="display:none;">
#       <div class="upload-res-txt clearfix">
#        <span class="upload-icon">
#        </span>
#        <div class="upload-res-input">
#         <h5>
#          New to Timesjobs?
#         </h5>
#         <label class="upload-res-btn" id="uploadResume_basic">
#          upload your resume
#          <input id="resumeFile_basic" name="resumeFile_basic" size="25" type="file"/>
#         </label>
#         <span id="uploadingResume_basic" style="display:none">
#          <img alt="Uploading Resume" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/loader.gif"/>
#         </span>
#        </div>
#       </div>
#      </div>
#     </div>
#     <script type="text/javascript">
#      var ssCounterSFB=0;
# 	function openSecondSuggestionSFB(theSelectedSuggestionText){
# 		if(ssCounterSFB < 5){
# 			ajaxController.getSuggestedSkillList(theSelectedSuggestionText,"","SKILL",8,true,cb_openSecondSuggestionSFB);
# 		}else{
# 			console.log("CAND-131 Not showing 2nd suggestion.");
# 		}
# 	}
#
# 	function cb_openSecondSuggestionSFB(result){
# 		//alert("cb_openSecondSuggestion:"+result);
# 		var splitData = (""+result).split(",");
# 		var li_data = "";
# 		var dataLength = splitData.length;
# 	    var text = jQuery("#txtKeywords").val();
# 	    text =text.toLowerCase();
# 	    if(dataLength >1){
# 			for(i=0;i<dataLength;i++){
# 	            if(text.indexOf(splitData[i].toLowerCase()) < 0){
# 	                var hyperlink =  "javascript:secondSelectionClickedSFB('"+encodeURI(splitData[i])+"');";
# 					li_data+="<li><a href="+hyperlink+">"+splitData[i]+"</a></li>";
# 				}
# 			}
# 			jQuery("#autoSuggestList2ndKeywordsListSFB ul").html(li_data);
# 			jQuery("#autoSuggestList2ndKeywordsListSFB").slideDown(300);
# 			//ssCounterSFB = ssCounterSFB  + 1;
# 		}
# 	}
#
# 	function secondSelectionClickedSFB(that){
# 		//alert("that:"+that);
# 		_gaq.push(['_trackEvent','Click2Ad','tj_skillsuggestion']);
# 		jQuery("#autoSuggestList2ndKeywordsListSFB").hide();
# 		var text = jQuery("#txtKeywords").val();
# 		var text2 = text.toLowerCase() + ",";
# 		var that2 = that.toLowerCase();
# 		var res = text2.split(",");
# 		var exists = false;
# 		for(i in res){
# 			if(null!=res[i] && res[i].length > 0 && res[i]+"".trim() === that2){
# 				exists = true;
# 				break;
# 			}
# 		}
# 		//var index = text2.search(new RegExp(that2, "i"));
# 		//console.log("exists:"+exists);
# 		if(!exists){
# 			jQuery("#txtKeywords").val(text +","+ that);
# 			jQuery("#txtKeywords").focus();
# 		}
# 		openSecondSuggestionSFB(that);
# 	}
# jQuery(document).ready(function(){
# 	jQuery('#quickSearchBean input[type="text"]').DefaultInputValue();
# })
#
# function BasicResFileUpload(){
# 		//alert('uploaded re loaded');
# 		new AjaxUpload('resumeFile_basic', {
# 			action:'/candidate/servlet/FileUploadServlet',
# 			//responseType: 'json',
# 			responseType: 'true',
# 			name: 'resumeFile_basic',
# 			onSubmit : function() {
# 				//alert('11');
# 				document.getElementById("uploadResume_basic").style.display="none";
# 				document.getElementById("uploadingResume_basic").style.display="block";
# 			},
# 			onComplete : function(file,response){
# 				var displayFilename=file;
# 				if(file.length >18){
# 					displayFilename=file.substring(0,18)+"..";
# 				}
# 				response = response.replace(/'/g , '"');
# 				var jsonObj = jQuery.parseJSON(response);
# 				jsonObj["filename"] = displayFilename;
# 				ajaxController.setSessionAttribute('tjindexResumeUploadMsg', jsonObj["MESSAGE"]);
# 				response = JSON.stringify(jsonObj);
# 				ajaxController.setSessionAttribute('tjindexResumeUpload', response);
# 				//window.open('/candidate/register.html', '_blank');
# 				window.location ='/candidate/register.html';
# 			}
# 		});
# 	}
# 	BasicResFileUpload();
#     </script>
#    </div>
#    <script>
#     var name='null';
# var phone='null';
# var email='null';
# //alert("name"+name);
# //alert("phone Num"+phone);
# if((phone!=null && $.trim(phone).length>0)&& phone.indexOf("+91-")!=-1){
#    phone = phone.replace("+91-",'');
# }
#
# FRESHCHAT_VISITORINFO={"name":name,"email":email,"phone":phone};
#    </script>
#    <script type="text/javascript">
#     //	alert("Hello");
# 	    var fc_CSS = document.createElement('link');
# 	    fc_CSS.setAttribute('rel', 'stylesheet');
# 	    var fc_isSecured = (window.location && window.location.protocol == 'https:');
# 	    var fc_lang = document.getElementsByTagName('html')[0].getAttribute('lang');
# 	    var fc_rtlLanguages = ['ar', 'he'];
# 	    var fc_rtlSuffix = (fc_rtlLanguages.indexOf(fc_lang) >= 0) ? '-rtl' : '';
# 	    fc_CSS.setAttribute('type', 'text/css');
# 	    fc_CSS.setAttribute('href', ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets1.chat.freshdesk.com') + '/css/visitor' + fc_rtlSuffix + '.css');
# 	    document.getElementsByTagName('head')[0].appendChild(fc_CSS);
# 	    var fc_JS = document.createElement('script');
# 	    fc_JS.type = 'text/javascript';
# 	    fc_JS.defer = true;
# 	    fc_JS.src = ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets.chat.freshdesk.com') + '/js/visitor.js';
# 	    (document.body ? document.body : document.getElementsByTagName('head')[0]).appendChild(fc_JS);
# 	    window.freshchat_setting = '...';
#    </script>
#    <script type="text/javascript">
#     if(document.getElementById("chat-widget") != undefined){
# document.getElementById("chat-widget").addEventListener("click", function(event){
#     event.preventDefault()
# });
# }
#    </script>
#    <script type="text/javascript">
#     $(function(){
# 			$('.nav-search').click(function(e){
# 				$('.common-search').slideToggle();
# 			});
# 			 $('.dropdown-button').dropdown({
# 				  inDuration: 300,
# 				  outDuration: 225,
# 				  constrainWidth: false,
# 				  hover: true,
# 				  gutter: 0,
# 				  belowOrigin: false,
# 				  alignment: 'left',
# 				  stopPropagation: false
# 			}
# 		  );
# 		});
#    </script>
#    <script>
#     jQuery(function() {
# 		//bottom banner starts
# 		jQuery('.bot-bnr').append('<span class="up-dwn-arrow"></span><span class="bot-bnr-cls"></span>');
# 		jQuery('.bot-bnr').addClass('bot-bnr-expnd',1000);
# 		setTimeout(function(){
# 		jQuery('.bot-bnr').removeClass('bot-bnr-expnd',1000);}, 5000);
# 		jQuery('.bot-bnr-cls').on("click", function() {
# 		  jQuery(this).parent("div").addClass('bot-bnr-csl',1000);
# 		});
# 		jQuery('.up-dwn-arrow').on("click", function() {
# 		  jQuery(this).parent("div").toggleClass('bot-bnr-expnd',1000);
# 		});
# 		//bottom banner ends
# 	});
#    </script>
#    <!-- Header Ends -->
#    <!-- Content Starts   -->
#    <div class="ubility-wrap clearfix">
#     <!--Cluster related page inclusion start here-->
#     <!--Cluster related page inclusion end here-->
#     <section class="ubility-lhs clearfix">
#      <div class="inside-lhs" id="search-result-cluster">
#       <div class="wht-bdr-bx tj-cluster">
#        <h4>
#         <i class="material-icons">
#          sort
#         </i>
#         Refined By
#        </h4>
#        <!--  <div id="clusterRefineHistoryId"></div>-->
#        <!--
#   <ul class="tab-filter clearfix">
#
#       <li class="tab-tc" id="tab-tc"><a href="#tabtc">Top Companies</a></li>
#
#
#     <li class="tab-jf" id="tab-jf"><a href="#tabjf">Job Function</a></li>
#
#
#
#       <li class="tab-ind" id="tab-ind"><a href="#tabind">Industry</a></li>
#
#
#
#
#       <li class="tab-sal" id="tab-sal"><a href="#tabsal">Salary</a></li>
#
#   </ul>
# -->
#        <div id="tj-tab-container-clusterId">
#         <div id="clusterDataInitial">
#          <ul class="collapsible" data-collapsible="expandable">
#           <li id="tabtc">
#            <div class="collapsible-header active">
#             <h6>
#              Companies
#             </h6>
#            </div>
#            <div class="cluster-scroll collapsible-body">
#             <ul>
#              <div id="comp_show">
#               <li>
#                <input id="com_0" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=python&amp;searchBy=0&amp;rdoOperator=OR&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=python&amp;cboWorkExp1=15&amp;undokey=compCluster&amp;compCluster=hp+enterprise+services&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=python&amp;searchBy=0&amp;rdoOperator=OR&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=python&amp;cboWorkExp1=15&amp;undokey=compCluster&amp;compCluster=hp+enterprise+services&amp;gadLink=View Jobs By This Company','Hp Enterprise Services');" type="checkbox"/>
#                <label for="com_0">
#                 <span title="Hp Enterprise Services">
#                  Hp Enterprise Services
#                 </span>
#                 <span class="grey-text">
#                  (30)
#                 </span>
#                </label>
#               </li>
#               <li>
#                <input id="com_1" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=python&amp;searchBy=0&amp;rdoOperator=OR&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=python&amp;cboWorkExp1=15&amp;undokey=compCluster&amp;compCluster=amazon+india+pvt+ltd&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=python&amp;searchBy=0&amp;rdoOperator=OR&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=python&amp;cboWorkExp1=15&amp;undokey=compCluster&amp;compCluster=amazon+india+pvt+ltd&amp;gadLink=View Jobs By This Company','Amazon India Pvt Ltd');" type="checkbox"/>
#                <label for="com_1">
#                 <span title="Amazon India Pvt Ltd">
#                  Amazon India Pvt Ltd
#                 </span>
#                 <span class="grey-text">
#                  (27)
#                 </span>
#                </label>
#               </li>
#               <li>
# ...
#    <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-1067146772">
#    </script>
#    <script>
#     window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'AW-1067146772');
#    </script>
#    <!-- New google pixel by sokrati -->
#    <script>
#     var parameter="";
# 	var regFlow="";
# 	var loginFlow="";
# 	var applyFlow="";
#
# 	regFlow="false";
# 	loginFlow="false";
# 	applyFlow="false";
#
# 	if(regFlow=="true")
# 	{
# 		parameter="_registrationFlow";
# 		ajaxController.trackCounter(parameter, "reg_3p9901_exp");
# 	}
# 	else if(loginFlow=="true"){
# 		var login = new RegExp("login.html", "i");
# 		if(!login.test(window.top.location) ){
# 			parameter="_loginFlow";
# 			ajaxController.trackCounter(parameter, "login_3p9901_exp");
# 		}
# 	}
#
# 	if(applyFlow=="true"){
# 		parameter="_applyFlow";
# 		ajaxController.trackCounter(parameter, "apply_3p9901_exp");
# 	}
#    </script>
#    <script src="//connect.facebook.net/en_US/sdk.js" type="text/javascript">
#    </script>
#    <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/fb_auto_connect.js?v=7.1.7" type="text/javascript">
#    </script>
#    <!-- Columbia AdTech(TIL) Code start Here -->
#    <script type="text/javascript">
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://static.clmbtech.com/ase/2320/34/aa.js';
#          var x = document.getElementsByTagName('script')[0];
#          x.parentNode.insertBefore(s, x);
#     })();
#    </script>
#    <!-- Columbia AdTech(TIL) Code end Here -->
#    <script type="text/javascript">
#     function freshWidgetCallback(){
# 		FreshWidget.init("", {"queryString": "&widgetType=popup&captcha=yes&searchArea=no", "backgroundImage": "https://www.ceoconnect.in/feedback/images/tj_feedback.gif", "utf8": "?", "widgetType": "popup", "buttonType": "image", "buttonText": "Support", "buttonColor": "black", "buttonBg": "#b8eaff", "alignment": "2", "offset": "145px", "formHeight": "500px", "captcha": "yes", "url": "https://timesjobs.freshdesk.com"} );
# 	}
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://assets.freshdesk.com/widget/freshwidget.js';
#          var x = document.getElementsByTagName('script')[0];
#          // most browsers
# 		s.onload = freshWidgetCallback;
# 		// IE 6 & 7
# 		s.onreadystatechange = function() {
# 			if (this.readyState == 'complete') {
# 				freshWidgetCallback();
# 			}
# 		}
#          x.parentNode.insertBefore(s, x);
#     })();
#    </script>
#    <!-- Facebook Pixel Code -->
#    <script>
#     !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '1727549374127582'); // Insert your pixel ID here.
# fbq('track', 'PageView');
#    </script>
#    <noscript>
#     <img height="1" src="https://www.facebook.com/tr?id=1727549374127582&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#    </noscript>
#    <!-- End Facebook Pixel Code -->
#    <!-- Footer Ends   -->
#    <script type="text/javascript">
#     var GB_ROOT_DIR = "/candidate/greybox/";
#    </script>
#    <link href="https://static.timesjobs.com/newtj_css/css/tj_css/personlisation/gb_styles.css" media="all" rel="stylesheet" type="text/css"/>
#    <script src="https://static.timesjobs.com/newtj_js/scripts/groupJs/searchResultTempGroup.js?v=7.1.7" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     var _sf_startpt=(new Date()).getTime()
#    </script>
#    <!--[if IE]><script src="https://static.timesjobs.com/newtj_js/scripts/html5.js"></script><![endif]-->
#    <script type="text/javascript">
#     var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6036484" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
#
#   function trackAjaxSRPresult(url, type) {
# 		var title = document.getElementsByTagName("title")[0].innerHTML;
# 		title = title.replace("TimesJobs.com", type + " Jobs");
# 		title = title.concat(" | TimesJobs.com");
#
# 		var t = "2", n = "6036484", r = "", i = encodeURIComponent(url), s = "", o = "", u = encodeURIComponent(title), a = "", f = "2.0", l = "1";
# 		var c = document.createElement("img");
# 		c.src = "https://sb.scorecardresearch.com/p?c1=" + t + "&c2=" + n +"&c3=" + r + "&c4=" + i + "&c5=" + s + "&c6=" + o + "&c8=" + u + "&c15=" + a + "&cv=" + f + "&cj=" + l + "&ns__t=" + (new Date).getTime();
# 		document.body.appendChild(c);
# 	}
#    </script>
#    <noscript>
#     <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6036484&amp;cv=2.0&amp;cj=1"/>
#    </noscript>
#    <script type="text/javascript">
#     /*!
# * jQuery Cookie Plugin v1.3.1
# * https://github.com/carhartl/jquery-cookie
# *
# * Copyright 2013 Klaus Hartl
# * Released under the MIT license
# */
# (function (factory) {
# if (typeof define === 'function' && define.amd && define.amd.jQuery) {
# // AMD. Register as anonymous module.
# define(['jquery'], factory);
# } else {
# // Browser globals.
# factory(jQuery);
# }
# }(function ($) {
#
# var pluses = /\+/g;
#
# function raw(s) {
# return s;
# }
#
# function decoded(s) {
# return decodeURIComponent(s.replace(pluses, ' '));
# }
#
# function converted(s) {
# if (s.indexOf('"') === 0) {
# // This is a quoted cookie as according to RFC2068, unescape
# s = s.slice(1, -1).replace(/\\"/g, '"').replace(/\\\\/g, '\\');
# }
# try {
# return config.json ? JSON.parse(s) : s;
# } catch(er) {}
# }
#
# var config = $.cookie = function (key, value, options) {
#
# // write
# if (value !== undefined) {
# options = $.extend({}, config.defaults, options);
#
# if (typeof options.expires === 'number') {
# var days = options.expires, t = options.expires = new Date();
# t.setDate(t.getDate() + days);
# }
#
# value = config.json ? JSON.stringify(value) : String(value);
#
# return (document.cookie = [
# encodeURIComponent(key), '=', config.raw ? value : encodeURIComponent(value),
# options.expires ? '; expires=' + options.expires.toUTCString() : '', // use expires attribute, max-age is not supported by IE
# options.path ? '; path=' + options.path : '',
# options.domain ? '; domain=' + options.domain : '',
# options.secure ? '; secure' : ''
# ].join(''));
# }
#
# // read
# var decode = config.raw ? raw : decoded;
# var cookies = document.cookie.split('; ');
# var result = key ? undefined : {};
# for (var i = 0, l = cookies.length; i < l; i++) {
# var parts = cookies[i].split('=');
# var name = decode(parts.shift());
# var cookie = decode(parts.join('='));
#
# if (key && key === name) {
# result = converted(cookie);
# break;
# }
#
# if (!key) {
# result[name] = converted(cookie);
# }
# }
#
# return result;
# };
#
# config.defaults = {};
#
# $.removeCookie = function (key, options) {
# if ($.cookie(key) !== undefined) {
# $.cookie(key, '', $.extend(options, { expires: -1 }));
# return true;
# }
# return false;
# };
#
# }));
#    </script>
#    <script type="text/javascript">
#     jQuery.cookie('previous_browser_url', $.cookie('current_browser_url'));
# 	jQuery.cookie('current_browser_url', window.location.href);
# 	//setCookie('previous_browser_url',getCookie('current_browser_url'));
# 	//setCookie('current_browser_url', window.location.href);
#    </script>
#    <script type="text/javascript">
#     function getPredefinedActionName(url){
# 		var returnActionName = "";
# 		var from = url.lastIndexOf("/");
# 		var to = url.indexOf("?",from);
# 		if(-1!=to){
# 			returnActionName = url.substring(from,to);
# 		}else{
# 			returnActionName = url.substring(from);
# 		}
# 		return returnActionName;
# 	}
#    </script>
#    <script type="text/javascript">
#     var notification_timeout = 10000;
# var notification_cache = true;
# function ping(url){
#  var ImageObject = new Image();
#  ImageObject.src = url; //e.g. logo
# }
# var cand_context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  cand_context="/candidate/";
# 		  //alert("bingo");
# 	}
#
# 		function getMailInBoxUnreadCount(){
# 			var rurl=cand_context+"inbox-message-get-unread-count.html";
# 			jQuery.ajax({
# 				cache:notification_cache,
# 				url:rurl,
# 				success:function(data){
# 					console.log("success... inbox-message-get-unread-count.html"+'');
# 				},
# 				error: function(x, textStatus, m) {
# 					console.log("Failed"+m);
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            //do something. Try again perhaps?
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    	}
# 			});
# 		}
#
# 		function getDistinctEmployerCounts(){
# 		 var rurl=cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_RE";
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:rurl,
# 			success:function(data){
# 				//alert("RE-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_re").html(data);
# 				jQuery("#mytj_header_re").html(data);
# 				jQuery("#homeindex_inbox_re").html(data);
# 				jQuery("#headerhome_inbox_re").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			            console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			            //do something. Try again perhaps?
# 			        }
# 		    }
#
# 		});
# 	//alert("call in progress...");
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV",
# 			success:function(data){
# 				//alert("PV-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_pv").html(data);
# 				jQuery("#mytj_header_pv").html(data);
# 				jQuery("#homeindex_inbox_pv").html(data);
# 				jQuery("#headerhome_inbox_pv").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV"+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    }
# 		});
# 	 }
# 	function displayLoading(div){
# 	if(1 == tab || 2 == tab || 4 == tab || 5 == tab  ){
# 			jQuery(div).append("<div class='loading'>&nbsp;</div>");
# 	}
# }
#    </script>
#    <script type="application/ld+json">
#     {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "location": {
#     "@type": "Place",
#     "address": "TimesJobs.com, Times Business Solutions (A Division of Times Internet Ltd.), Times Center (Digital Content Production Facility), FC - 6, (Ground Floor), Sector 16 A, Film City, NOIDA - 201 301, Uttar Pradesh, India"
#   },
#   "name": "TimesJobs.com",
#   "description": "TimesJobs: India's Leading Job Portal",
#   "logo": "https://static.timesjobs.com/images_cand/tj_images/logos/tj_logo_300x300.jpg",
#   "url": "https://www.timesjobs.com",
#   "email": "timesjobs@timesgroup.com"
# }
#    </script>
#    <script type="application/ld+json">
#     {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "https://www.timesjobs.com",
#     "potentialAction": {
#       "@type": "SearchAction",
#       "target": "https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords={search_term_string}",
#       "query-input": "required name=search_term_string"
#     }
# }
#    </script>
#    <!--Common Template Included in all files end here  -->
#    <!--google analytics start-->
#    <script type="text/javascript">
#     var _gaq = _gaq || [];
#
#
#
#
#
#
#
#
# 			_gaq.push(['_setAccount', 'UA-1688637-1']);
#
#
#   _gaq.push(['_trackPageview']);
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
#   function trackClickEvent(category,action){
# 		_gaq.push(['_trackEvent',category,action]);
# 	}
#    </script>
#    <!--google analytics ends-->
#    <img alt="" border="0" height="1" src="https://tracking.sokrati.com/site?client_id=60&amp;product_category=Site_Search" width="1"/>
#    <script type="text/javascript">
#     function removeSpecificRefineNew(urltoHit){
#  	getSRPResultByDwrNew(urltoHit);
#  	return false;
#  }
#
#  function getSRPResultByDwrNew(urlToHit) {
# 		jQuery( "#refine-opt-search-datewise a" ).removeClass( "refinejobsopt" );
# 		jQuery("#defualtSelectedDate").addClass( "refinejobsopt" );
# 		jQuery("#searchResultData").remove();
# 		jQuery("#searchResultContents").html(dataImageLoader);
# 		var matchStr=urlToHit.match("&undo=(.*)&undoValue");//For Selecting tab on Cluster
#
# 		ajaxController.getDWRBasedWebResponse(urlToHit,function(data) {
# 							if (data != null && data != 'undefined') {
# 								jQuery("#searchResultContents").html(data);
#
# 								console.info("matchStr=="+matchStr);
# 								if(chkNull(matchStr)){
# 									console.info("matched text at posotion 1="+matchStr[1]);
# 									showSelectedTabData(matchStr[1]);
# 								}
# 								if(matchStr==null && urlToHit.indexOf("undo=")!=-1){
# 									//jQuery( ".refined-bx" ).tabs("refresh");
#
# 								}
# 								//For making initial tab selected
# 								if(urlToHit.indexOf("&reset")!=-1){
# 									console.info("inside reset all tab");
# 									//jQuery( ".refined-bx" ).tabs("refresh");
# 								}
# 							} else {
# 								jQuery("#searchResultContents").html("Oops! There seems to be a technical problem. Please try again");
# 							}
# 						});
# 						return false;
# 	}
#
#
#
# 	if (top != self){
# 		window.open(self.location.href,"_top");
# 	}
# 	var siteId='1040';
# 	var stype = 'timesjobs.com';
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://ceoconnect.in/feedback/scripts/feedbackInc.js';
#          var x = document.getElementsByTagName('script')[0];
#          x.parentNode.insertBefore(s, x);
#     })();
#    </script>
#   </div>
#   <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/lightBox.js" type="text/javascript">
#   </script>
#   <div class="modal" id="light-box-popup">
#    <span class="material-icons close-modal modal-action modal-close">
#     close
#    </span>
#    <div class="modal-content" id="light-box-popup-content">
#    </div>
#   </div>
#   <!-- <script type="text/javascript">
#   $(document).ready(function(){
# 	    // the "href" attribute of the modal trigger must specify the modal ID that wants to be triggered
# 	    $('.modal').modal();
# 	  });
#
#   </script> -->
#   <!--  ##########################  JobBuzz Ads  ################## -->
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"applicationID":"96890711","applicationTime":315,"beacon":"bam-cell.nr-data.net","queueTime":0,"licenseKey":"2a67c1bd6d","transactionName":"NgdTbUEHV0JYBUZYWQ9Ne2pjSW50e0t7f3BOCEJJHBNKUFsPXlhCGE1FXF4WVVBNAx1SVw8GWF1SElxiXAdAUl4TB0JMXxJtVFQWXlBCBExbSkM=","agent":"","errorBeacon":"bam-cell.nr-data.net"}
#   </script>
#  </body>
# </html>

# %% [markdown]
# ### Only One Job

# %%
job = soup.find('li', class_='clearfix job-bx wht-shd-bx')
print(job)
# Out:
# <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/python-capgemini-pune-12-to-15-yrs-jobid-SnD3Qy3u93RzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','67021822','security compliance  ,  python  ,  html5  ,  mobile  ,  javascript  ,  database  ,  django  ,  python scripting','Pune','12 - 15','IT Software : Software Products &amp; Services','1' )" target="_blank">
# <strong class="blkclor">Python</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     capgemini
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>12 - 15 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Pune">Pune</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Job DescriptionExperience in Python ,  with knowledge of at least one Python web framework ,  such as Django ,  Flask ,  etc depending on your technology stackFamiliarity with... <a href="https://www.timesjobs.com/job-detail/python-capgemini-pune-12-to-15-yrs-jobid-SnD3Qy3u93RzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           security compliance  ,  <strong class="blkclor">python</strong>  ,  html5  ,  mobile  ,  javascript  ,  database  ,  django  ,  <strong class="blkclor">python</strong> scripting
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Pune
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_67021822">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('67021822','adId=SnD3Qy3u93RzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','67021822','security compliance  ,  python  ,  html5  ,  mobile  ,  javascript  ,  database  ,  django  ,  python scripting','Pune','12 - 15','IT Software : Software Products &amp; Services','1')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>

# %%
company_name = job.find('h3', class_='joblist-comp-name')
print(company_name)
# Out:
# <h3 class="joblist-comp-name">
#     capgemini
#
#     </h3>

# %%
company_name = job.find('h3', class_='joblist-comp-name').text.strip()
print('Company: ',company_name)
# Out:
# Company:  capgemini

# %%
skill = job.find('span', class_='srp-skills').text.strip()
print('Skill: ',skill)
# Out:
# Skill:  security compliance  ,  python  ,  html5  ,  mobile  ,  javascript  ,  database  ,  django  ,  python scripting

# %%
published_date = job.find('span', class_='sim-posted').text.strip()
print('Posted Date: ',published_date)
# Out:
# Posted Date:  Posted few days ago

# %%
published_date = job.find('span', class_='sim-posted').span.text.strip()
print('Posted Date: ',published_date)
# Out:
# Posted Date:  Posted few days ago

# %% [markdown]
# ### Jobs on Single Page

# %%
jobs = soup.find_all('li', class_='clearfix job-bx wht-shd-bx')
print(jobs)
# Out:
# [<li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/python-capgemini-pune-12-to-15-yrs-jobid-SnD3Qy3u93RzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','67021822','security compliance  ,  python  ,  html5  ,  mobile  ,  javascript  ,  database  ,  django  ,  python scripting','Pune','12 - 15','IT Software : Software Products &amp; Services','1' )" target="_blank">
# <strong class="blkclor">Python</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     capgemini
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>12 - 15 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Pune">Pune</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Job DescriptionExperience in Python ,  with knowledge of at least one Python web framework ,  such as Django ,  Flask ,  etc depending on your technology stackFamiliarity with... <a href="https://www.timesjobs.com/job-detail/python-capgemini-pune-12-to-15-yrs-jobid-SnD3Qy3u93RzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           security compliance  ,  <strong class="blkclor">python</strong>  ,  html5  ,  mobile  ,  javascript  ,  database  ,  django  ,  <strong class="blkclor">python</strong> scripting
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Pune
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_67021822">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('67021822','adId=SnD3Qy3u93RzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','67021822','security compliance  ,  python  ,  html5  ,  mobile  ,  javascript  ,  database  ,  django  ,  python scripting','Pune','12 - 15','IT Software : Software Products &amp; Services','1')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/python-developer-applycup-hiring-solutions-llp-gurgaon-delhi-delhi-ncr-2-to-15-yrs-jobid-FHYQtX1BOyxzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','65602057','python  ,  django  ,  html5  ,  javascript','Gurgaon,  Delhi,  Delhi/NCR','2 - 15','IT Software : Software Products &amp; Services','2' )" target="_blank">
# <strong class="blkclor">Python</strong> Developer</a> </h2>
# <h3 class="joblist-comp-name">
#     APPLYCUP HIRING SOLUTIONS LLP
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>2 - 15 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Gurgaon,  Delhi,  Delhi/NCR">Gurgaon,  Delhi,  Delhi/NCR</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Python DeveloperGurgaon ,  Delhi Qualification : Any Graduate Experience : 2 - 15 YearsSkills : Python ,  Django ,  FlaskJob Description :Job Description:Expert in Python ,  w... <a href="https://www.timesjobs.com/job-detail/python-developer-applycup-hiring-solutions-llp-gurgaon-delhi-delhi-ncr-2-to-15-yrs-jobid-FHYQtX1BOyxzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
# <strong class="blkclor">python</strong>  ,  django  ,  html5  ,  javascript
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Gurgaon,  Delhi,  Delhi/NCR
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_65602057">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('65602057','adId=FHYQtX1BOyxzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','65602057','python  ,  django  ,  html5  ,  javascript','Gurgaon,  Delhi,  Delhi/NCR','2 - 15','IT Software : Software Products &amp; Services','2')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/python-developer-saggezza-india-pvt-ltd-14-to-17-yrs-jobid-EKcTZ__SLASH__6q2FBzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66640215','fundamentals  ,  algorithms  ,  salesforce  ,  java  ,  technology consulting  ,  data structures  ,  mongodb  ,  python  ,  nosql  ,  infrastructure','','14 - 17','IT Software : Software Products &amp; Services','3' )" target="_blank">
# <strong class="blkclor">Python</strong> Developer</a> </h2>
# <h3 class="joblist-comp-name">
#     SAGGEZZA INDIA PVT LTD
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>14 - 17 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title=""></span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Designing and implementing large-scale backend infrastructure and APIs.Writing high quality code that is robust ,  readable and scales.Possess the drive to dive deep ,  thrive... <a href="https://www.timesjobs.com/job-detail/python-developer-saggezza-india-pvt-ltd-14-to-17-yrs-jobid-EKcTZ__SLASH__6q2FBzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           fundamentals  ,  algorithms  ,  salesforce  ,  java  ,  technology consulting  ,  data structures  ,  mongodb  ,  <strong class="blkclor">python</strong>  ,  nosql  ,  infrastructure
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66640215">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66640215','adId=EKcTZ__SLASH__6q2FBzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66640215','fundamentals  ,  algorithms  ,  salesforce  ,  java  ,  technology consulting  ,  data structures  ,  mongodb  ,  python  ,  nosql  ,  infrastructure','','14 - 17','IT Software : Software Products &amp; Services','3')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
#        <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/engineering-manager-python-java-forstaffing-noida-greater-noida-15-to-18-yrs-jobid-eC6K9sGJoFZzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','65712373','Python  ,  kanban  ,  Java','Noida/Greater Noida','15 - 18','IT Software : Software Products &amp; Services','4' )" target="_blank">
#       Engineering Manager  ( <strong class="blkclor">Python</strong> /  Java ) </a> </h2>
# <h3 class="joblist-comp-name">
#     Forstaffing
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>15 - 18 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Noida/Greater Noida">Noida/Greater Noida</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Do you like the idea of playing Master Shifu for product development teams? Or ,  what organizations think of it as playing an Engineering Manager.Do you live by the mantra of... <a href="https://www.timesjobs.com/job-detail/engineering-manager-python-java-forstaffing-noida-greater-noida-15-to-18-yrs-jobid-eC6K9sGJoFZzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
# <strong class="blkclor">Python</strong>  ,  kanban  ,  Java
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Noida/Greater Noida
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_65712373">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('65712373','adId=eC6K9sGJoFZzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','65712373','Python  ,  kanban  ,  Java','Noida/Greater Noida','15 - 18','IT Software : Software Products &amp; Services','4')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/staff-engineer-python-distributed-nutanix-bengaluru-bangalore-12-to-15-yrs-jobid-43JO6hk__PLUS__8ghzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','67116257','san  ,  python  ,  c    ,  c  ,  system software  ,  problem solving  ,  infrastructure','Bengaluru / Bangalore','12 - 15','IT Software : Software Products &amp; Services','5' )" target="_blank">
#       Staff Engineer-[<strong class="blkclor">Python</strong> ,  Distributed]</a> </h2>
# <h3 class="joblist-comp-name">
#     Nutanix
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>12 - 15 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Design and develop next generation one-click cluster lifecycle management capabilities in core Nutanix distributed clusterScale your software to a massively distributed infras... <a href="https://www.timesjobs.com/job-detail/staff-engineer-python-distributed-nutanix-bengaluru-bangalore-12-to-15-yrs-jobid-43JO6hk__PLUS__8ghzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           san  ,  <strong class="blkclor">python</strong>  ,  c    ,  c  ,  system software  ,  problem solving  ,  infrastructure
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_67116257">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('67116257','adId=43JO6hk__PLUS__8ghzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','67116257','san  ,  python  ,  c    ,  c  ,  system software  ,  problem solving  ,  infrastructure','Bengaluru / Bangalore','12 - 15','IT Software : Software Products &amp; Services','5')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
#        <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 6 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/senior-python-django-developer-contactpoint-360-cochin-kochi-ernakulam-12-to-15-yrs-jobid-5CBWqiIv4ClzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66915342','storage  ,  sql  ,  security  ,  testing tools  ,  devops  ,  python  ,  cloud services  ,  django','Cochin/ Kochi/ Ernakulam','12 - 15','IT Software : Software Products &amp; Services','6' )" target="_blank">
#       Senior <strong class="blkclor">Python</strong>  ( Django )  Developer</a> </h2>
# <h3 class="joblist-comp-name">
#     contactpoint 360
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>12 - 15 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Cochin/ Kochi/ Ernakulam">Cochin/ Kochi/ Ernakulam</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# We are looking for an experienced  ( 4-5 years )  Python developer to join our engineering team and help us create dynamic software applications for our clients. In this role ... <a href="https://www.timesjobs.com/job-detail/senior-python-django-developer-contactpoint-360-cochin-kochi-ernakulam-12-to-15-yrs-jobid-5CBWqiIv4ClzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           storage  ,  sql  ,  security  ,  testing tools  ,  devops  ,  <strong class="blkclor">python</strong>  ,  cloud services  ,  django
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Cochin/ Kochi/ Ernakulam
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66915342">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66915342','adId=5CBWqiIv4ClzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66915342','storage  ,  sql  ,  security  ,  testing tools  ,  devops  ,  python  ,  cloud services  ,  django','Cochin/ Kochi/ Ernakulam','12 - 15','IT Software : Software Products &amp; Services','6')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
#        <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/sse-python-django-forstaffing-gurgaon-12-to-15-yrs-jobid-PoCDLGTlta9zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66899633','rest  ,  python  ,  css  ,  javascript  ,  django  ,  html  ,  mysql  ,  service oriented architecture  ,  soap','Gurgaon','12 - 15','IT Software : Software Products &amp; Services','7' )" target="_blank">
#       SSE- <strong class="blkclor">Python</strong>   Django</a> </h2>
# <h3 class="joblist-comp-name">
#     Forstaffing
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>12 - 15 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Gurgaon">Gurgaon</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# - Python- Django framework- HTML ,  CSS and Javascript- REST APIs- MySQL- ORM  ( SQLAlchemy ,  Django-ORM etc ) - SOAP / REST web servicesRole:Coordinate with the business tea... <a href="https://www.timesjobs.com/job-detail/sse-python-django-forstaffing-gurgaon-12-to-15-yrs-jobid-PoCDLGTlta9zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           rest  ,  <strong class="blkclor">python</strong>  ,  css  ,  javascript  ,  django  ,  html  ,  mysql  ,  service oriented architecture  ,  soap
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Gurgaon
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66899633">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66899633','adId=PoCDLGTlta9zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66899633','rest  ,  python  ,  css  ,  javascript  ,  django  ,  html  ,  mysql  ,  service oriented architecture  ,  soap','Gurgaon','12 - 15','IT Software : Software Products &amp; Services','7')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/python-java-data-engineer-saggezza-india-pvt-ltd-14-to-17-yrs-jobid-__PLUS__dZQ33BP5mhzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66925219','algorithms  ,  c    ,  scala  ,  sql  ,  salesforce  ,  java  ,  technology consulting  ,  linux  ,  data structures  ,  big data  ,  mongodb  ,  python  ,  junit  ,  sybase  ,  c  ,  problem solving  ,  nosql  ,  project delivery','','14 - 17','IT Software : Software Products &amp; Services','8' )" target="_blank">
# <strong class="blkclor">Python</strong> / Java   Data Engineer</a> </h2>
# <h3 class="joblist-comp-name">
#     SAGGEZZA INDIA PVT LTD
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>14 - 17 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title=""></span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# We provide strategic and innovative consulting services focused on digital experiences , engineering ,  automation ,  data and analytics ,  and salesforce solutions. Saggezza ... <a href="https://www.timesjobs.com/job-detail/python-java-data-engineer-saggezza-india-pvt-ltd-14-to-17-yrs-jobid-__PLUS__dZQ33BP5mhzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           algorithms  ,  c    ,  scala  ,  sql  ,  salesforce  ,  java  ,  technology consulting  ,  linux  ,  data structures  ,  big data  ,  mongodb  ,  <strong class="blkclor">python</strong>  ,  junit  ,  sybase  ,  c  ,  problem solving  ,  nosql  ,  project delivery
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66925219">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66925219','adId=__PLUS__dZQ33BP5mhzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66925219','algorithms  ,  c    ,  scala  ,  sql  ,  salesforce  ,  java  ,  technology consulting  ,  linux  ,  data structures  ,  big data  ,  mongodb  ,  python  ,  junit  ,  sybase  ,  c  ,  problem solving  ,  nosql  ,  project delivery','','14 - 17','IT Software : Software Products &amp; Services','8')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
#        <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/004429.gif" alt="Extreme Networks India Pvt Ltd" title="Extreme Networks India Pvt Ltd"/> </span> -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/principal-software-engineer-python-development-extreme-networks-india-pvt-ltd-bengaluru-bangalore-12-to-15-yrs-jobid-QDWQ4SC__SLASH__T89zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','67139261','artificial intelligence  ,  docker  ,  java  ,  git  ,  devops  ,  linux  ,  software engineer  ,  software life cycle  ,  python  ,  oracle  ,  svn  ,  machine learning  ,  infrastructure  ,  forms','Bengaluru / Bangalore','12 - 15','IT Software : Software Products &amp; Services','9' )" target="_blank">
#       Principal Software Engineer - <strong class="blkclor">Python</strong> Development</a> </h2>
# <h3 class="joblist-comp-name">
#     Extreme Networks India Pvt Ltd
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>12 - 15 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Experience Level : 12 years Be part of the Automation Infrastructure and webtool team to develop various applications automation solutions for Engineering wired org. Provide s... <a href="https://www.timesjobs.com/job-detail/principal-software-engineer-python-development-extreme-networks-india-pvt-ltd-bengaluru-bangalore-12-to-15-yrs-jobid-QDWQ4SC__SLASH__T89zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           artificial intelligence  ,  docker  ,  java  ,  git  ,  devops  ,  linux  ,  software engineer  ,  software life cycle  ,  <strong class="blkclor">python</strong>  ,  oracle  ,  svn  ,  machine learning  ,  infrastructure  ,  forms
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_67139261">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('67139261','adId=QDWQ4SC__SLASH__T89zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','67139261','artificial intelligence  ,  docker  ,  java  ,  git  ,  devops  ,  linux  ,  software engineer  ,  software life cycle  ,  python  ,  oracle  ,  svn  ,  machine learning  ,  infrastructure  ,  forms','Bengaluru / Bangalore','12 - 15','IT Software : Software Products &amp; Services','9')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 2 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/hiring-full-stack-developer-reactjs-nodejs-python-glan-management-consultancy-pvt-ltd-mumbai-8-to-20-yrs-jobid-xywJrj4x6sVzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66146007','css  ,  information technology  ,  html5  ,  git  ,  html  ,  python  ,  mobile  ,  javascript  ,  node.js','Mumbai','8 - 20','IT Software : Software Products &amp; Services','10' )" target="_blank">
#       Hiring Full stack developer - ReactJS / NodeJS / <strong class="blkclor">Python</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     glan management consultancy pvt. ltd.
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>8 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Mumbai">Mumbai</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# As a Full Stack Developer ,  you will work on a eCommerce project to elevate the digital experience for the mobile and web eCommerce and Personalization experiences across mul... <a href="https://www.timesjobs.com/job-detail/hiring-full-stack-developer-reactjs-nodejs-python-glan-management-consultancy-pvt-ltd-mumbai-8-to-20-yrs-jobid-xywJrj4x6sVzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           css  ,  information technology  ,  html5  ,  git  ,  html  ,  <strong class="blkclor">python</strong>  ,  mobile  ,  javascript  ,  node.js
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Mumbai
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66146007">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66146007','adId=xywJrj4x6sVzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66146007','css  ,  information technology  ,  html5  ,  git  ,  html  ,  python  ,  mobile  ,  javascript  ,  node.js','Mumbai','8 - 20','IT Software : Software Products &amp; Services','10')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/software-development-engineer-c-c-python-viasat-inc-chennai-8-to-15-yrs-jobid-oKSmUIoH6q1zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66739866','algorithms  ,  protocol stack  ,  c    ,  software design  ,  docker  ,  satellite communication  ,  devops  ,  data structures  ,  satellite  ,  python  ,  c  ,  written communication','Chennai','8 - 15','IT Software : Software Products &amp; Services','11' )" target="_blank">
#       Software Development Engineer  C ,  C   ,  <strong class="blkclor">Python</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     Viasat Inc.
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>8 - 15 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Chennai">Chennai</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Job description Bigger challenges. Bolder ideas. Global impact. At Viasat ,  we are on a mission to deliver connections with the capacity to change the world. We are the compa... <a href="https://www.timesjobs.com/job-detail/software-development-engineer-c-c-python-viasat-inc-chennai-8-to-15-yrs-jobid-oKSmUIoH6q1zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           algorithms  ,  protocol stack  ,  c    ,  software design  ,  docker  ,  satellite communication  ,  devops  ,  data structures  ,  satellite  ,  <strong class="blkclor">python</strong>  ,  c  ,  written communication
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Chennai
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66739866">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66739866','adId=oKSmUIoH6q1zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66739866','algorithms  ,  protocol stack  ,  c    ,  software design  ,  docker  ,  satellite communication  ,  devops  ,  data structures  ,  satellite  ,  python  ,  c  ,  written communication','Chennai','8 - 15','IT Software : Software Products &amp; Services','11')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/senior-backend-developer-node-js-python-aws-glan-management-consultancy-pvt-ltd-mumbai-7-to-20-yrs-jobid-ZOII5LjoCUZzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66110871','css  ,  software design  ,  postgresql  ,  cake  ,  j2ee  ,  html  ,  mysql  ,  python  ,  javascript  ,  node.js  ,  written communication','Mumbai','7 - 20','IT Software : Software Products &amp; Services','12' )" target="_blank">
#       senior backend developer - Node.js / <strong class="blkclor">Python</strong> / AWS</a> </h2>
# <h3 class="joblist-comp-name">
#     glan management consultancy pvt. ltd.
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>7 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Mumbai">Mumbai</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Job Description:Position: Backend Developer  ( Node.JS ,  python ,  amazon aws )  Location: Mumbai Experience: 7-20 year Salary: NegotiableRequirements : - Must have 7  years ... <a href="https://www.timesjobs.com/job-detail/senior-backend-developer-node-js-python-aws-glan-management-consultancy-pvt-ltd-mumbai-7-to-20-yrs-jobid-ZOII5LjoCUZzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           css  ,  software design  ,  postgresql  ,  cake  ,  j2ee  ,  html  ,  mysql  ,  <strong class="blkclor">python</strong>  ,  javascript  ,  node.js  ,  written communication
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Mumbai
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66110871">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66110871','adId=ZOII5LjoCUZzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66110871','css  ,  software design  ,  postgresql  ,  cake  ,  j2ee  ,  html  ,  mysql  ,  python  ,  javascript  ,  node.js  ,  written communication','Mumbai','7 - 20','IT Software : Software Products &amp; Services','12')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/002068.gif" alt="QuEST Global Engineering Pvt Ltd" title="QuEST Global Engineering Pvt Ltd"/> </span> -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/technical-architect-python-full-stack-power-domain-referral-quest-global-engineering-pvt-ltd-bengaluru-bangalore-12-to-15-yrs-jobid-WZ74QSa__PLUS__A__SLASH__9zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66951683','security  ,  postgresql  ,  web development  ,  python  ,  javascript','Bengaluru / Bangalore','12 - 15','IT Software : Software Products &amp; Services','13' )" target="_blank">
#       Technical Architect - <strong class="blkclor">Python</strong> Full Stack  ( Power Domain )  - Referral</a> </h2>
# <h3 class="joblist-comp-name">
#     QuEST Global Engineering Pvt Ltd
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>12 - 15 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Responsibilities:Should be able to quickly build complete domain and technical knowledge of various modules of the softwareProvide solution architecture and lead specification... <a href="https://www.timesjobs.com/job-detail/technical-architect-python-full-stack-power-domain-referral-quest-global-engineering-pvt-ltd-bengaluru-bangalore-12-to-15-yrs-jobid-WZ74QSa__PLUS__A__SLASH__9zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           security  ,  postgresql  ,  web development  ,  <strong class="blkclor">python</strong>  ,  javascript
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66951683">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66951683','adId=WZ74QSa__PLUS__A__SLASH__9zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66951683','security  ,  postgresql  ,  web development  ,  python  ,  javascript','Bengaluru / Bangalore','12 - 15','IT Software : Software Products &amp; Services','13')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 2 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/senior-software-engineer-c-c-python-network-protocols-viasat-inc-chennai-8-to-15-yrs-jobid-99SN95Z6catzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','67145445','c    ,  protocol development  ,  network programming  ,  devops  ,  software engineering  ,  telecom  ,  satellite  ,  object oriented programming  ,  python  ,  c  ,  written communication','Chennai','8 - 15','IT Software : Software Products &amp; Services','14' )" target="_blank">
#       Senior Software engineer  C ,  C   / <strong class="blkclor">Python</strong> ,  Network Protocols</a> </h2>
# <h3 class="joblist-comp-name">
#     Viasat Inc.
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>8 - 15 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Chennai">Chennai</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Job ResponsibilitiesYou will work with a world class team developing and deploying new technologies on a cutting edge network. You will design ,  develop and deploy new and in... <a href="https://www.timesjobs.com/job-detail/senior-software-engineer-c-c-python-network-protocols-viasat-inc-chennai-8-to-15-yrs-jobid-99SN95Z6catzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           c    ,  protocol development  ,  network programming  ,  devops  ,  software engineering  ,  telecom  ,  satellite  ,  object oriented programming  ,  <strong class="blkclor">python</strong>  ,  c  ,  written communication
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Chennai
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_67145445">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('67145445','adId=99SN95Z6catzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','67145445','c    ,  protocol development  ,  network programming  ,  devops  ,  software engineering  ,  telecom  ,  satellite  ,  object oriented programming  ,  python  ,  c  ,  written communication','Chennai','8 - 15','IT Software : Software Products &amp; Services','14')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 1 day ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/000019.gif" alt="ABC Consultants Pvt Ltd" title="ABC Consultants Pvt Ltd"/> </span> -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail
zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66984627','sql  ,  database  ,  mongodb  ,  python  ,  c','New York City','8 - 15','IT Software : Software Products &amp; Services','25' )" target="_blank">
#       Business Operations Senior Manager</a> </h2>
# <h3 class="joblist-comp-name">
#     MongoDB Software India Pvt Ltd.
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>8 - 15 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="New York City">New York City</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# MongoDB is seeking a Senior Manager of Business Operations to help drive strategic and operational initiatives across MongoDB. In this role you will sit at the intersection of... <a href="https://www.timesjobs.com/job-detail/business-operations-senior-manager-mongodb-software-india-pvt-ltd-new-york-city-8-to-15-yrs-jobid-DF0__PLUS__cF53JZZzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           sql  ,  database  ,  mongodb  ,  <strong class="blkclor">python</strong>  ,  c
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               New York City
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66984627">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66984627','adId=DF0__PLUS__cF53JZZzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66984627','sql  ,  database  ,  mongodb  ,  python  ,  c','New York City','8 - 15','IT Software : Software Products &amp; Services','25')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 1 day ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>]

# %%
for job in jobs:
    print()
    position = job.find('h2').text.strip()
    print('Position: ', position)
    company_name = job.find('h3', class_='joblist-comp-name').text.strip()
    print('Company: ',company_name)
    skill = job.find('span', class_='srp-skills').text.strip()
    print('Skill: ',skill)
    published_date = job.find('span', class_='sim-posted').span.text.strip()
    print('Posted Date: ',published_date)
    more_info = job.header.h2.a['href']
    print('More info: ', more_info)
    print()
    print('----------------------------------------------------------------')
# Out:
# Position:  Python
# Company:  capgemini
# Skill:  security compliance  ,  python  ,  html5  ,  mobile  ,  javascript  ,  database  ,  django  ,  python scripting
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/python-capgemini-pune-12-to-15-yrs-jobid-SnD3Qy3u93RzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  Python Developer
# Company:  APPLYCUP HIRING SOLUTIONS LLP
# Skill:  python  ,  django  ,  html5  ,  javascript
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/python-developer-applycup-hiring-solutions-llp-gurgaon-delhi-delhi-ncr-2-to-15-yrs-jobid-FHYQtX1BOyxzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  Python Developer
# Company:  SAGGEZZA INDIA PVT LTD
# Skill:  fundamentals  ,  algorithms  ,  salesforce  ,  java  ,  technology consulting  ,  data structures  ,  mongodb  ,  python  ,  nosql  ,  infrastructure
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/python-developer-saggezza-india-pvt-ltd-14-to-17-yrs-jobid-EKcTZ__SLASH__6q2FBzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  Engineering Manager  ( Python /  Java )
# Company:  Forstaffing
# Skill:  Python  ,  kanban  ,  Java
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/engineering-manager-python-java-forstaffing-noida-greater-noida-15-to-18-yrs-jobid-eC6K9sGJoFZzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  Staff Engineer-[Python ,  Distributed]
# Company:  Nutanix
# Skill:  san  ,  python  ,  c    ,  c  ,  system software  ,  problem solving  ,  infrastructure
# Posted Date:  Posted 6 days ago
# More info:  https://www.timesjobs.com/job-detail/staff-engineer-python-distributed-nutanix-bengaluru-bangalore-12-to-15-yrs-jobid-43JO6hk__PLUS__8ghzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  Senior Python  ( Django )  Developer
# Company:  contactpoint 360
# Skill:  storage  ,  sql  ,  security  ,  testing tools  ,  devops  ,  python  ,  cloud services  ,  django
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-python-django-developer-contactpoint-360-cochin-kochi-ernakulam-12-to-15-yrs-jobid-5CBWqiIv4ClzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  SSE- Python   Django
# Company:  Forstaffing
# Skill:  rest  ,  python  ,  css  ,  javascript  ,  django  ,  html  ,  mysql  ,  service oriented architecture  ,  soap
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/sse-python-django-forstaffing-gurgaon-12-to-15-yrs-jobid-PoCDLGTlta9zpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  Python / Java   Data Engineer
# Company:  SAGGEZZA INDIA PVT LTD
# Skill:  algorithms  ,  c    ,  scala  ,  sql  ,  salesforce  ,  java  ,  technology consulting  ,  linux  ,  data structures  ,  big data  ,  mongodb  ,  python  ,  junit  ,  sybase  ,  c  ,  problem solving  ,  nosql  ,  project delivery
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/python-java-data-engineer-saggezza-india-pvt-ltd-14-to-17-yrs-jobid-__PLUS__dZQ33BP5mhzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  Principal Software Engineer - Python Development
# Company:  Extreme Networks India Pvt Ltd
# Skill:  artificial intelligence  ,  docker  ,  java  ,  git  ,  devops  ,  linux  ,  software engineer  ,  software life cycle  ,  python  ,  oracle  ,  svn  ,  machine learning  ,  infrastructure  ,  forms
# Posted Date:  Posted 2 days ago
# More info:  https://www.timesjobs.com/job-detail/principal-software-engineer-python-development-extreme-networks-india-pvt-ltd-bengaluru-bangalore-12-to-15-yrs-jobid-QDWQ4SC__SLASH__T89zpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  Hiring Full stack developer - ReactJS / NodeJS / Python
# Company:  glan management consultancy pvt. ltd.
# Skill:  css  ,  information technology  ,  html5  ,  git  ,  html  ,  python  ,  mobile  ,  javascript  ,  node.js
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/hiring-full-stack-developer-reactjs-nodejs-python-glan-management-consultancy-pvt-ltd-mumbai-8-to-20-yrs-jobid-xywJrj4x6sVzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  Software Development Engineer  C ,  C   ,  Python
# Company:  Viasat Inc.
# Skill:  algorithms  ,  protocol stack  ,  c    ,  software design  ,  docker  ,  satellite communication  ,  devops  ,  data structures  ,  satellite  ,  python  ,  c  ,  written communication
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/software-development-engineer-c-c-python-viasat-inc-chennai-8-to-15-yrs-jobid-oKSmUIoH6q1zpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  senior backend developer - Node.js / Python / AWS
# Company:  glan management consultancy pvt. ltd.
# Skill:  css  ,  software design  ,  postgresql  ,  cake  ,  j2ee  ,  html  ,  mysql  ,  python  ,  javascript  ,  node.js  ,  written communication
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-backend-developer-node-js-python-aws-glan-management-consultancy-pvt-ltd-mumbai-7-to-20-yrs-jobid-ZOII5LjoCUZzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  Technical Architect - Python Full Stack  ( Power Domain )  - Referral
# Company:  QuEST Global Engineering Pvt Ltd
# Skill:  security  ,  postgresql  ,  web development  ,  python  ,  javascript
# Posted Date:  Posted 2 days ago
# More info:  https://www.timesjobs.com/job-detail/technical-architect-python-full-stack-power-domain-referral-quest-global-engineering-pvt-ltd-bengaluru-bangalore-12-to-15-yrs-jobid-WZ74QSa__PLUS__A__SLASH__9zpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  Senior Software engineer  C ,  C   / Python ,  Network Protocols
# Company:  Viasat Inc.
# Skill:  c    ,  protocol development  ,  network programming  ,  devops  ,  software engineering  ,  telecom  ,  satellite  ,  object oriented programming  ,  python  ,  c  ,  written communication
# Posted Date:  Posted 1 day ago
# More info:  https://www.timesjobs.com/job-detail/senior-software-engineer-c-c-python-network-protocols-viasat-inc-chennai-8-to-15-yrs-jobid-99SN95Z6catzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  SPE / Associate Director- Technology
# Company:  ABC Consultants Pvt Ltd
# Skill:  python  ,  java  ,   JVM language  ,   Python
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/spe-associate-director-technology-abc-consultants-pvt-ltd-hyderabad-secunderabad-bengaluru-bangalore-15-to-18-yrs-jobid-5oYjmSby6vJzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  Technical Specialist
# Company:  Nokia Siemens Networks Ltd
# Skill:  python  ,  information technology  ,  tcl
# Posted Date:  Posted 6 days ago
# More info:  https://www.timesjobs.com/job-detail/technical-specialist-nokia-siemens-networks-ltd-chennai-12-to-15-yrs-jobid-ZsIFVPL__PLUS__feBzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  Incorta Lead  /  Architect
# Company:  AugmatrixGo
# Skill:  python  ,  sql  ,  PySpark
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/incorta-lead-architect-augmatrixgo-hyderabad-secunderabad-10-to-15-yrs-jobid-s__SLASH__X__SLASH__6qerU9JzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  Sr. Architect  Full STack
# Company:  Talent Corner Hr Services Private Limited
# Skill:  python  ,  devops  ,  php
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/sr-architect-full-stack-talent-corner-hr-services-private-limited-hyderabad-secunderabad-indore-mumbai-delhi-delhi-ncr-13-to-16-yrs-jobid-Hzlr8kf__PLUS__HtlzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  VP Engineering
# Company:  FresherMart
# Skill:  python  ,  mobile  ,  salesforce  ,  mysql
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/vp-engineering-freshermart-bengaluru-bangalore-12-to-15-yrs-jobid-8Mlx8O30h59zpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  Engineering Manager
# Company:  Kissflow
# Skill:  python  ,  technical skills  ,  mongodb
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/engineering-manager-kissflow-chennai-12-to-15-yrs-jobid-VQY4eDVhwGVzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  Analytics - Machine Learning  &  Statistical Modeling Projects
# Company:  Analytics Vidhya
# Skill:  python  ,  c  ,  machine learning
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/analytics-machine-learning-statistical-modeling-projects-analytics-vidhya-bengaluru-bangalore-8-to-15-yrs-jobid-mH0XdTM9RhNzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  PreSilicon FPGA Validation Engineer
# Company:  Intel Technology India Pvt Ltd
# Skill:  python  ,  c    ,  c
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/presilicon-fpga-validation-engineer-intel-technology-india-pvt-ltd-bengaluru-bangalore-7-to-15-yrs-jobid-Pdibv78yh7BzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  Intel inSilicon FPGA Validation Engineer
# Company:  Intel Technologies
# Skill:  python  ,  c    ,  c
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/intel-insilicon-fpga-validation-engineer-intel-technologies-bengaluru-bangalore-7-to-15-yrs-jobid-W1__PLUS__pnEwDjxZzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  Architect
# Company:  RGF Professional
# Skill:  python  ,  nosql  ,  java  ,  devops
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/architect-rgf-professional-pune-15-to-18-yrs-jobid-i7zuMUe9VBpzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------
#
# Position:  Business Operations Senior Manager
# Company:  MongoDB Software India Pvt Ltd.
# Skill:  sql  ,  database  ,  mongodb  ,  python  ,  c
# Posted Date:  Posted 1 day ago
# More info:  https://www.timesjobs.com/job-detail/business-operations-senior-manager-mongodb-software-india-pvt-ltd-new-york-city-8-to-15-yrs-jobid-DF0__PLUS__cF53JZZzpSvf__PLUS__uAgZw==&source=srp
#
# ----------------------------------------------------------------

# %% [markdown]
# ## Jobs on All Pages

# %%
# fetch page number bar
bar = soup.find('div', class_='srp-pagination clearfix')
print(bar)
# Out:
# <div class="srp-pagination clearfix">
# <em class="active">1</em><em><a href="#" onclick="getNextPageResult(2,1)" rel="next">2</a></em><em><a href="#" onclick="getNextPageResult(3,1)" rel="next">3</a></em><em><a href="#" onclick="getNextPageResult(4,1)" rel="next">4</a></em><em><a href="#" onclick="getNextPageResult(5,1)" rel="next">5</a></em><em><a href="#" onclick="getNextPageResult(6,1)" rel="next">6</a></em><em><a href="#" onclick="getNextPageResult(7,1)" rel="next">7</a></em><em><a href="#" onclick="getNextPageResult(8,1)" rel="next">8</a></em><em><a href="#" onclick="getNextPageResult(9,1)" rel="next">9</a></em><em><a href="#" onclick="getNextPageResult(10,1)" rel="next">10</a></em><em class="nxtC"><a href="#" onclick="getNextPageResult(11,11)" rel="next"> Next 10 pages </a></em>
# </div>

# %%
# fetch sequences(page numbers and current page)
sequence = bar.find_all('em')
print(sequence)
for seq in sequence:
    print(seq)
# Out:
# [<em class="active">1</em>, <em><a href="#" onclick="getNextPageResult(2,1)" rel="next">2</a></em>, <em><a href="#" onclick="getNextPageResult(3,1)" rel="next">3</a></em>, <em><a href="#" onclick="getNextPageResult(4,1)" rel="next">4</a></em>, <em><a href="#" onclick="getNextPageResult(5,1)" rel="next">5</a></em>, <em><a href="#" onclick="getNextPageResult(6,1)" rel="next">6</a></em>, <em><a href="#" onclick="getNextPageResult(7,1)" rel="next">7</a></em>, <em><a href="#" onclick="getNextPageResult(8,1)" rel="next">8</a></em>, <em><a href="#" onclick="getNextPageResult(9,1)" rel="next">9</a></em>, <em><a href="#" onclick="getNextPageResult(10,1)" rel="next">10</a></em>, <em class="nxtC"><a href="#" onclick="getNextPageResult(11,11)" rel="next"> Next 10 pages </a></em>]
# <em class="active">1</em>
# <em><a href="#" onclick="getNextPageResult(2,1)" rel="next">2</a></em>
# <em><a href="#" onclick="getNextPageResult(3,1)" rel="next">3</a></em>
# <em><a href="#" onclick="getNextPageResult(4,1)" rel="next">4</a></em>
# <em><a href="#" onclick="getNextPageResult(5,1)" rel="next">5</a></em>
# <em><a href="#" onclick="getNextPageResult(6,1)" rel="next">6</a></em>
# <em><a href="#" onclick="getNextPageResult(7,1)" rel="next">7</a></em>
# <em><a href="#" onclick="getNextPageResult(8,1)" rel="next">8</a></em>
# <em><a href="#" onclick="getNextPageResult(9,1)" rel="next">9</a></em>
# <em><a href="#" onclick="getNextPageResult(10,1)" rel="next">10</a></em>
# <em class="nxtC"><a href="#" onclick="getNextPageResult(11,11)" rel="next"> Next 10 pages </a></em>

# %%
# find current page
print(bar.find('em', class_='active'))
# Out:
# <em class="active">1</em>

# %%
# find last page
print(sequence[-1].text)
# Out:
#  Next 10 pages

# %% [markdown]
# ### Start Code

# %%
# import modules
from bs4 import BeautifulSoup
import requests

# %%
base_url = 'https://www.timesjobs.com/'
my_job = input('Job: ')
experience = input("Enter only number.\nFor all experience, only press 'enter'.\nExperience: ")
# Out:
# Job: python
# Enter only number.
# For all experience, only press 'enter'.
# Experience: 15

# %%
seq = 1   # set page no

# fetch data until the last page
while True:

    # create url to fetch data on one page after another page
    '''
    Sample URL:
    https://www.timesjobs.com/candidate/job-search.html?from=submit&actualTxtKeywords=python
    &searchBy=0&rdoOperator=OR&searchType=personalizedSearch&luceneResultSize=25&
    postWeek=60&txtKeywords=python&cboWorkExp1=15&pDate=I&sequence=1&startPage=1
    '''
    
    startPage = 1 + ((seq-1)//10)*10  # formula for startPage query

    # generate URL
    url = base_url + '/candidate/job-search.html?from=submit&txtKeywords=' + my_job+'&cboWorkExp1='+\
            experience+'&sequence='+str(seq)+'&startPage='+str(startPage)

    # fetch HTMl text
    html_text = requests.get(url).text

    # parse HTML text using 'lxml'
    soup = BeautifulSoup(html_text, 'lxml')
    jobs = soup.find_all('li', class_='clearfix job-bx wht-shd-bx')

    # loop all jobs and dispaly each job details.
    for job in jobs:
        print()
        # find required data in HTML tags
        position = job.find('h2').text.strip()
        print('Position: ', position)
        company_name = job.find('h3', class_='joblist-comp-name').text.strip()
        print('Company: ',company_name)
        skill = job.find('span', class_='srp-skills').text.strip()
        print('Skill: ',skill)
        published_date = job.find('span', class_='sim-posted').span.text.strip()
        print('Posted Date: ',published_date)
        more_info = job.header.h2.a['href']
        print('More info: ', more_info)
        print()
        print('-----------------------------------------------------------------')

    # after one page, move to another page
    # check the page number bar and find current page number
    bar = soup.find('div', class_='srp-pagination clearfix')


    # get all  page numbers on the bar
    sequence_bar = bar.find_all('em')


    # check the current page is the last page
    is_last_page = bar.find('em', class_='active').text == sequence_bar[-1].text

    # if current page is the last page, terminate loop.
    # else, move to another page and fetch data.
    if is_last_page:
        break

    # increase page number to fectch data    
    seq = seq+1
# Out:
# Streaming output truncated to the last 5000 lines.
# Position:  Senior SD Lead /  Manager
# Company:  Intel Technologies
# Skill:  perl  ,  tcl  ,  python  ,  written communication
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior
zpSvf__PLUS__uAgZw==&source=srp
#
# -----------------------------------------------------------------
#
# Position:  Test Automation Analyst ,  VP
# Company:  Credit Suisse Securities  ( India )  Pvt Ltd
# Skill:  fundamentals  ,  shell scripting  ,  perl  ,  c#  ,  python  ,  simulator  ,  unix
# Posted Date:  Posted a month ago
# More info:  https://www.timesjobs.com/job-detail/test-automation-analyst-vp-credit-suisse-securities-india-pvt-ltd-pune-12-to-15-yrs-jobid-VJ3bMB3AaBBzpSvf__PLUS__uAgZw==&source=srp
#
# -----------------------------------------------------------------
#
# Position:  Senior Build and Release Engineer  ( Devops Engineer )
# Company:  APPLYCUP HIRING SOLUTIONS LLP
# Skill:  c    ,  docker  ,  git  ,  java  ,  devops  ,  linux  ,  perl  ,  perforce  ,  github  ,  python  ,  c  ,  svn  ,  ruby  ,  release engineer  ,  unix
# Posted Date:  Posted 1 day ago
# More info:  https://www.timesjobs.com/job-detail/senior-build-and-release-engineer-devops-engineer-applycup-hiring-solutions-llp-bengaluru-bangalore-5-to-15-yrs-jobid-9TzygLKDTOtzpSvf__PLUS__uAgZw==&source=srp
#
# -----------------------------------------------------------------
#
# Position:  Multimedia  &  IOT Test Architect
# Company:  PathPartner Technology
# Skill:  algorithms  ,  c    ,  docker  ,  rtos  ,  linux  ,  shell scripting  ,  middleware  ,  python  ,  dts  ,  c  ,  video codecs  ,  nfc  ,  multimedia  ,  infrastructure
# Posted Date:  Posted 2 days ago
# More info:  https://www.timesjobs.com/job-detail/multimedia-iot-test-architect-pathpartner-technology-bengaluru-bangalore-9-to-15-yrs-jobid-JJVp5vXFucVzpSvf__PLUS__uAgZw==&source=srp
#
# -----------------------------------------------------------------
#
# Position:  Lead GPU Verification Engineer
# Company:  Advanced Micronic Devices Ltd
# Skill:  ece  ,  graphics  ,  script language  ,  linux  ,  perl  ,  python  ,  c  ,  c   programming  ,  windows
# Posted Date:  Posted 3 days ago
# More info:  https://www.timesjobs.com/job-detail/lead-gpu-verification-engineer-advanced-micronic-devices-ltd-hyderabad-secunderabad-bengaluru-bangalore-12-to-15-yrs-jobid-vmho__PLUS__UORjJRzpSvf__PLUS__uAgZw==&source=srp
#
# -----------------------------------------------------------------
#
# Position:  RPA  &  Lean Process Automation
# Company:  FIS GLOBAL BUSINESS SOLUTIONS INDIA PVT. LTD
# Skill:  artificial intelligence  ,  security  ,  shell scripting  ,  bpm  ,  python  ,  problem solving  ,  machine learning  ,  production support  ,  groovy  ,  infrastructure  ,  pega
# Posted Date:  Posted 3 days ago
# More info:  https://www.timesjobs.com/job-detail/rpa-lean-process-automation-fis-global-business-solutions-india-pvt-ltd-pune-bengaluru-bangalore-12-to-15-yrs-jobid-jAzdeaVZZDVzpSvf__PLUS__uAgZw==&source=srp
#
# -----------------------------------------------------------------
#
# Position:  Machine Learning Engineer
# Company:  SEVEN CONSULTANCY
# Skill:  fundamentals  ,  algorithms  ,  artificial intelligence  ,  java  ,  data structures  ,  python  ,  natural language processing  ,  machine learning  ,  consultant
# Posted Date:  Posted 1 day ago
# ...
#
# -----------------------------------------------------------------
#
# Position:  Principal Engineer GPU Performance Verification
# Company:  Intel Technologies
# Skill:  soc  ,  rtl coding  ,  system verilog  ,  verification  ,  hardware  ,  hardware engineering  ,  verification engineer  ,  hardware design
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/principal-engineer-gpu-performance-verification-intel-technologies-hyderabad-secunderabad-15-to-18-yrs-jobid-m1FScnwLDdFzpSvf__PLUS__uAgZw==&source=srp
#
# -----------------------------------------------------------------
#
# Position:  Senior Manager - Business Analytics
# Company:  AMAZON INDIA PVT LTD
# Skill:  visualization  ,  business requirements  ,  bi  ,  security  ,  requirement gathering  ,  java  ,  data science  ,  software packages  ,  functional requirements  ,  business analytics  ,  tableau  ,  business process  ,  written communication  ,  forms
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-manager-business-analytics-amazon-india-pvt-ltd-bengaluru-bangalore-12-to-15-yrs-jobid-M4ffAvT__SLASH__vjtzpSvf__PLUS__uAgZw==&source=srp
#
# -----------------------------------------------------------------
#
# Position:  Divisional Manager -TW  ( Data  &  Analytics )
# Company:  SKILLVENTORY
# Skill:  nbfc  ,  lending  ,  loans  ,  divisional manager  ,  business analyst  ,  financial services  ,  risk  ,  unsecured loans
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail
zpSvf__PLUS__uAgZw==&source=srp
#
# -----------------------------------------------------------------
#
# Position:  FPGA IP Design Engineer
# Company:  Intel Technologies
# Skill:  rtl design  ,  fpga  ,  rtl coding  ,  system verilog  ,  verification  ,  hardware  ,  altera  ,  verilog  ,  fpga design  ,  pcie
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/fpga-ip-design-engineer-intel-technologies-bengaluru-bangalore-12-to-15-yrs-jobid-Yl3cGqWg__SLASH__sdzpSvf__PLUS__uAgZw==&source=srp
#
# -----------------------------------------------------------------
#
# Position:  EUC Remediation - Lead Data Analyst  ( VP )
# Company:  Citibank India
# Skill:  business requirements  ,  database  ,  data structures  ,  data visualization  ,  data analysis  ,  os  ,  data analyst  ,  tableau
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/euc-remediation-lead-data-analyst-vp-citibank-india-pune-12-to-16-yrs-jobid-s__SLASH__9SyjctvWpzpSvf__PLUS__uAgZw==&source=srp
#
# -----------------------------------------------------------------
#
# Position:  Senior Project Manager / Markets  &  Sec Services IT
# Company:  HSBC
# Skill:  pmp  ,  java  ,  senior project manager  ,  project management  ,  unix  /  linux  ,  technical lead  ,  technical leader  ,  solution architect  ,  scrum master
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-project-manager-markets-sec-services-it-hsbc-pune-15-to-18-yrs-jobid-bAJbsJ1VOYJzpSvf__PLUS__uAgZw==&source=srp
#
# -----------------------------------------------------------------
#
# Position:  Senior Project Manager / Markets  &  Sec Services IT
# Company:  HSBC
# Skill:  pmp  ,  java  ,  senior project manager  ,  project management  ,  unix  /  linux  ,  technical lead  ,  technical leader  ,  solution architect  ,  scrum master
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-project-manager-markets-sec-services-it-hsbc-pune-15-to-18-yrs-jobid-LJbi78BY__PLUS__LhzpSvf__PLUS__uAgZw==&source=srp
#
# -----------------------------------------------------------------
#
# Position:  Infrastructure  Lead Network Consultant
# Company:  Infosys Technologies Ltd
# Skill:  cisco routing  ,  ccnp  ,  f5  ,  juniper  ,  switching  ,  load balancing  ,  ccie  ,  cisco  ,  wan
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/infrastructure-lead-network-consultant-infosys-technologies-ltd-singapore-12-to-15-yrs-jobid-74s__SLASH__GH8W1HZzpSvf__PLUS__uAgZw==&source=srp
#
# -----------------------------------------------------------------
#
# Position:  Test Manager
# Company:  Standard Chartered Bank Ltd
# Skill:  continuous integration  ,  test automation  ,  cucumber  ,  qa  ,  java  ,  pl  /  sql  ,  oracle  ,  testing  ,  test manager  ,  agile  ,  unix  ,  performance testing  ,  test scripts  ,  jprofiler  ,  webload  ,  jmeter  ,  sql  ,  test data  ,  database  ,  selenium  ,  test strategy  ,  writing  ,  jenkins  ,  perl  ,  test scenarios
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/test-manager-standard-chartered-bank-ltd-chennai-12-to-15-yrs-jobid-duzMWhW0279zpSvf__PLUS__uAgZw==&source=srp
#
# -----------------------------------------------------------------
#
# Position:  Sr. IT Security Officer
# Company:  Vocera
# Skill:  c    ,  information technology  ,  forensic  ,  code review  ,  cisa  ,  IT security  ,  director  ,  vulnerability  ,  ids  ,  unix  ,  cissp  ,  security  ,  linux  ,  penetration testing  ,  san  ,  c  ,  data security  ,  information security  ,  windows  ,  cism  ,  security architecture  ,  written communication  ,  infrastructure  ,  forensic investigations
# Posted Date:  Posted a month ago
# More info:  https://www.timesjobs.com/job-detail/sr-it-security-officer-vocera-12-to-15-yrs-jobid-CWHDXKkLlPBzpSvf__PLUS__uAgZw==&source=srp
#
# -----------------------------------------------------------------
#
# Position:  Senior Manager
# Company:  Tejas Network Ltd
# Skill:  switching  ,  networking products  ,  routing  ,  mpls  ,  gigabit ethernet  ,  protocols  ,  data networking  ,  broadband
# Posted Date:  Posted a month ago
# More info:  https://www.timesjobs.com/job-detail/senior-manager-tejas-network-ltd-bengaluru-bangalore-10-to-15-yrs-jobid-PSTmlJ4Sx5ZzpSvf__PLUS__uAgZw==&source=srp
#
# -----------------------------------------------------------------
#
# Position:  Automation Test Analyst-UFT ,  AVP-VP
# Company:  Credit Suisse Securities  ( India )  Pvt Ltd
# Skill:  test automation  ,  test management  ,  test cases  ,  qa  ,  java  ,  jira  ,  life cycle  ,  alm  ,  sql queries  ,  testing  ,  vb  ,  test engineer  ,  gui
# Posted Date:  Posted a month ago
# More info:  https://www.timesjobs.com/job-detail